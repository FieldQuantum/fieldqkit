# %% [markdown]
# # F2 分子 VQE 教程（12-Qubit Active Space）
#
# 目标：
# - 使用 WSL 端导出的 F2 12 比特哈密顿量
# - 构建可调参数的 custom ansatz
# - 运行 VQE 并与 FCI 参考值比较

# %% [markdown]
# ## 1. 参数配置
# F2 采用如下 active-space 规则：freeze 1a1,2a1,3a1,4a1；active 1e1,2e1,3e1,4e1,5a1,6a1（对应 12 qubits）。

# %%
from pathlib import Path
import json
import math

# Geometry / chemistry config
R = 2.6
R_UNIT = 'angstrom'
BASIS = 'sto-3g'
MULTIPLICITY = 1
CHARGE = 0

# VQE config
cfg = {
    'layers': 2,
    'shots': 4096,
    'max_iters': 20,
    'learning_rate': 0.1,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2,
}

print('R =', R, R_UNIT)
print('Basis =', BASIS)
print('VQE cfg =', cfg)
# Out:
# R = 2.6 angstrom
# Basis = sto-3g
# VQE cfg = {'layers': 2, 'shots': 4096, 'max_iters': 20, 'learning_rate': 0.1, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %% [markdown]
# ## 2. 读取 WSL 导出的 12-qubit 哈密顿量
# 默认文件：`data/chemistry/f2_R2.6_angstrom_sto-3g_12q.json`
#
# 若文件不存在，请在 WSL 中执行：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_f2.sh 2.6 angstrom
# ```

# %%
from __future__ import annotations

import os
import json
from pathlib import Path

# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner

json_path = Path(f'data/chemistry/f2_R{R:.1f}_{R_UNIT}_sto-3g_12q.json')
data = json.loads(json_path.read_text(encoding='utf-8'))

f2_constant = float(data['constant'])
f2_12q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded from:', json_path)
print('nqubits:', nqubits)
print('term_count:', len(f2_12q_terms))
print('fci_energy:', fci_energy)
# Out:
# Loaded from: data\chemistry\f2_R2.6_angstrom_sto-3g_12q.json
# nqubits: 12
# term_count: 382
# fci_energy: -195.9734686096283

# %% [markdown]
# ## 3. 构建 F2 12-qubit Custom Ansatz
# F2共18个电子，冻结最低4个轨道后还剩10个电子和6个轨道，因此HF态是|111111111100>
# 结合对称性限制和激发能量，只考虑UCC中的最关键项，包括
#
# $$
# a_{11}^\dagger a_{10}^\dagger a_1 a_0, \quad a_{11}^\dagger a_{10}^\dagger a_3 a_2, \quad a_{11}^\dagger a_{10}^\dagger a_5 a_4, \quad a_{11}^\dagger a_{10}^\dagger a_7 a_6, \quad a_{11}^\dagger a_{10}^\dagger a_9 a_8
# $$
#
# 对应的UCC为
#
# $$
# U(\theta) =
# \exp\left[-i\theta_5 Y_8 X_9 X_{10} Y_{11} -i\theta_4 Y_6 X_7 Z_8 Z_9 X_{10} Y_{11} - i\theta_3 Y_4 X_5 Z_6 Z_7 Z_8 Z_9 X_{10} Y_{11} - i\theta_2 Y_2 X_3 Z_4 Z_5 Z_6 Z_7 Z_8 Z_9 X_{10} Y_{11} - i\theta_1 Y_0 X_1 Z_2 Z_3 Z_4 Z_5 Z_6 Z_7 Z_8 Z_9 X_{10} Y_{11}
# \right]
# $$

# %%
from quantum_hw.circuit import QuantumCircuit

def build_f2_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(12)

    # HF state or "singlet" reference state
    qc.ry("theta_0", 8)
    qc.cx(8, 9)
    qc.cx(9, 10)
    qc.cx(10, 11)

    for q in range(10):
        qc.x(q)

    qc.pauli_evolution("theta_1", "Y0 X1 Z2 Z3 Z4 Z5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_2", "Y2 X3 Z4 Z5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_3", "Y4 X5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_4", "Y6 X7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_5", "Y8 X9 X10 Y11")

    return qc

custom_ansatz_qc = build_f2_symbolic_ansatz()
symbolic_params = sorted(
    [k for k, v in custom_ansatz_qc.params_value.items() if isinstance(k, str) and isinstance(v, str)]
)
print('Total gates in custom F2 ansatz:', len(custom_ansatz_qc.gates))
print('Parameter count:', len(symbolic_params))
# Out:
# Total gates in custom F2 ansatz: 149
# Parameter count: 6

# %% [markdown]
# ## 4. 运行 VQE（模拟器）

# %%
runner = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
)

kwargs = {
    'name': 'f2_12q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': f2_12q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01] * len(symbolic_params),
}

res = runner.run_model(**kwargs)
e_total = f2_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 12-Qubit F2 VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + f2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Total Energy (Hartree)')
plt.title(f'F2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=f2_12q_custom num_qubits=12 model=custom layers=2 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=2 params=6 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-5.620472 grad_norm=0.392761
# [vqe] iter 0 new best energy=-5.620472
# [vqe] iter 1 start
# [vqe] iter 1 energy=-5.654690 grad_norm=0.387943
# [vqe] iter 1 new best energy=-5.654690
# [vqe] iter 2 start
# [vqe] iter 2 energy=-5.697846 grad_norm=0.381258
# [vqe] iter 2 new best energy=-5.697846
# [vqe] iter 3 start
# [vqe] iter 3 energy=-5.734263 grad_norm=0.369368
# [vqe] iter 3 new best energy=-5.734263
# [vqe] iter 4 start
# [vqe] iter 4 energy=-5.768479 grad_norm=0.354162
# [vqe] iter 4 new best energy=-5.768479
# [vqe] iter 5 start
# [vqe] iter 5 energy=-5.804712 grad_norm=0.336466
# [vqe] iter 5 new best energy=-5.804712
# [vqe] iter 6 start
# [vqe] iter 6 energy=-5.838585 grad_norm=0.314591
# [vqe] iter 6 new best energy=-5.838585
# [vqe] iter 7 start
# [vqe] iter 7 energy=-5.866764 grad_norm=0.291052
# [vqe] iter 7 new best energy=-5.866764
# [vqe] iter 8 start
# [vqe] iter 8 energy=-5.892833 grad_norm=0.266197
# [vqe] iter 8 new best energy=-5.892833
# [vqe] iter 9 start
# [vqe] iter 9 energy=-5.918523 grad_norm=0.234943
# [vqe] iter 9 new best energy=-5.918523
# [vqe] iter 10 start
# [vqe] iter 10 energy=-5.939775 grad_norm=0.202795
# [vqe] iter 10 new best energy=-5.939775
# [vqe] iter 11 start
# [vqe] iter 11 energy=-5.955328 grad_norm=0.179317
# [vqe] iter 11 new best energy=-5.955328
# [vqe] iter 12 start
# [vqe] iter 12 energy=-5.969636 grad_norm=0.147857
# [vqe] iter 12 new best energy=-5.969636
# [vqe] iter 13 start
# [vqe] iter 13 energy=-5.981678 grad_norm=0.105119
# [vqe] iter 13 new best energy=-5.981678
# [vqe] iter 14 start
# [vqe] iter 14 energy=-5.988119 grad_norm=0.088681
# [vqe] iter 14 new best energy=-5.988119
# [vqe] iter 15 start
# [vqe] iter 15 energy=-5.992096 grad_norm=0.078481
# [vqe] iter 15 new best energy=-5.992096
# [vqe] iter 16 start
# [vqe] iter 16 energy=-5.995506 grad_norm=0.028084
# [vqe] iter 16 new best energy=-5.995506
# [vqe] iter 17 start
# [vqe] iter 17 energy=-5.995203 grad_norm=0.042236
# [vqe] iter 18 start
# [vqe] iter 18 energy=-5.992819 grad_norm=0.076759
# [vqe] iter 19 start
# [vqe] iter 19 energy=-5.991258 grad_norm=0.066585
# === 12-Qubit F2 VQE Result ===
# Estimated total energy:   -195.97203031
# FCI reference energy:     -195.97346861
# Absolute error vs FCI:    0.0014383

# %% [markdown]
# ## 5. 在真实硬件上运行（可选）
# 按需启用 ZNE / REM / Clifford Fitting。

# %%
cfg['prefer_chips'] = 'Baihua'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
cfg['gradient_method'] = 'parameter-shift'
cfg['measuremet_mode'] = 'grouped'
from time import sleep
sleep(36000)
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    measurement_mode=cfg['measuremet_mode'],
    clifford_fitting=cfg['clifford_fitting'],
    clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
)

kwargs = {
    'name': 'f2_12q_custom_hw',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': f2_12q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.0] * len(symbolic_params),
}

res_hw = runner_cmp.run_model(**kwargs)
e_total_hw = f2_constant + res_hw.best_energy
abs_error_fci_hw = abs(e_total_hw - fci_energy)

print('=== 12-Qubit F2 Hardware VQE Result ===')
print('Estimated total energy:  ', round(e_total_hw, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci_hw, 8))

# %% [markdown]
# ## 6. 计算完整的能量曲线
# 按不同键长 R 扫描 F2 的势能面，并与每个 R 对应的 FCI 参考值比较。

# %%
import numpy as np

R_scan = np.arange(1.0, 3.01, 0.3)
energy_ucc = []
cfg['gradient_method'] = 'autograd'
# Keep scan on simulator to avoid accidental hardware submissions.
scan_cfg = {
    'layers': cfg['layers'],
    'shots': cfg['shots'],
    'max_iters': cfg['max_iters'],
    'learning_rate': cfg['learning_rate'],
    'gradient_method': cfg['gradient_method'],
    'seed': cfg['seed'],
    'shift': cfg['shift'],
    'prefer_chips': 'Simulator',
}

for R_now in R_scan:
    json_path = Path(f'data/chemistry/f2_R{R_now:.1f}_angstrom_sto-3g_12q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))

    f2_constant_now = float(data['constant'])
    f2_terms_now = [(float(c), str(obs)) for c, obs in data['terms']]
    nqubits_now = int(data['nqubits'])
    fci_energy_now = float(data['fci_energy'])

    runner_scan = VQERunner(
        client=QuantumHardwareClient(),
        layers=scan_cfg['layers'],
        shots=scan_cfg['shots'],
        max_iters=scan_cfg['max_iters'],
        learning_rate=scan_cfg['learning_rate'],
        gradient_method=scan_cfg['gradient_method'],
        seed=scan_cfg['seed'],
        shift=scan_cfg['shift'],
    )

    kwargs_scan = {
        'name': f'f2_12q_custom_R{R_now:.1f}',
        'num_qubits': nqubits_now,
        'model': 'custom',
        'hamiltonian': f2_terms_now,
        'ansatz': 'custom',
        'custom_ansatz_circuit': custom_ansatz_qc,
        'prefer_chips': scan_cfg['prefer_chips'],
        'init_params': [0.0] * len(symbolic_params),
    }

    res_scan = runner_scan.run_model(**kwargs_scan)
    e_total_now = f2_constant_now + res_scan.best_energy

    energy_ucc.append({
        'R': R_now,
        'e_total': e_total_now,
        'fci': fci_energy_now,
    })

print('scan points =', len(energy_ucc))
print('first point =', energy_ucc[0] if energy_ucc else None)
print('last point  =', energy_ucc[-1] if energy_ucc else None)
# Out:
# [vqe] prepare run: name=f2_12q_custom_R1.0 num_qubits=12 model=custom layers=2 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=2 params=6 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=
# [vqe] iter 1 start
# [vqe] iter 1 energy=-5.587478 grad_norm=0.397725
# [vqe] iter 1 new best energy=-5.587478
# [vqe] iter 2 start
# [vqe] iter 2 energy=-5.626924 grad_norm=0.390667
# [vqe] iter 2 new best energy=-5.626924
# [vqe] iter 3 start
# [vqe] iter 3 energy=-5.665445 grad_norm=0.379716
# [vqe] iter 3 new best energy=-5.665445
# [vqe] iter 4 start
# [vqe] iter 4 energy=-5.702632 grad_norm=0.364999
# [vqe] iter 4 new best energy=-5.702632
# [vqe] iter 5 start
# [vqe] iter 5 energy=-5.738083 grad_norm=0.346699
# [vqe] iter 5 new best energy=-5.738083
# [vqe] iter 6 start
# [vqe] iter 6 energy=-5.771413 grad_norm=0.325059
# [vqe] iter 6 new best energy=-5.771413
# [vqe] iter 7 start
# [vqe] iter 7 energy=-5.802263 grad_norm=0.300380
# [vqe] iter 7 new best energy=-5.802263
# [vqe] iter 8 start
# [vqe] iter 8 energy=-5.829517 grad_norm=0.274077
# [vqe] iter 8 new best energy=-5.829517
# [vqe] iter 9 start
# [vqe] iter 9 energy=-5.854065 grad_norm=0.246100
# [vqe] iter 9 new best energy=-5.854065
# [vqe] iter 10 start
# [vqe] iter 10 energy=-5.876339 grad_norm=0.214009
# [vqe] iter 10 new best energy=-5.876339
# [vqe] iter 11 start
# [vqe] iter 11 energy=-5.894363 grad_norm=0.183236
# [vqe] iter 11 new best energy=-5.894363
# [vqe] iter 12 start
# [vqe] iter 12 energy=-5.909064 grad_norm=0.152424
# [vqe] iter 12 new best energy=-5.909064
# [vqe] iter 13 start
# [vqe] iter 13 energy=-5.921085 grad_norm=0.115648
# [vqe] iter 13 new best energy=-5.921085
# [vqe] iter 14 start
# [vqe] iter 14 energy=-5.928523 grad_norm=0.094417
# [vqe] iter 14 new best energy=-5.928523
# [vqe] iter 15 start
# [vqe] iter 15 energy=-5.934227 grad_norm=0.059553
# [vqe] iter 15 new best energy=-5.934227
# [vqe] iter 16 start
# [vqe] iter 16 energy=-5.936813 grad_norm=0.038128
# [vqe] iter 16 new best energy=-5.936813
# [vqe] iter 17 start
# [vqe] iter 17 energy=-5.936683 grad_norm=0.053202
# [vqe] iter 18 start
# [vqe] iter 18 energy=-5.936176 grad_norm=0.035651
# [vqe] iter 19 start
# [vqe] iter 19 energy=-5.933088 grad_norm=0.073642
# scan points = 7
# first point = {'R': np.float64(1.0), 'e_total': -195.63959213514235, 'fci': -195.6610863183076}
# last point  = {'R': np.float64(2.8000000000000003), 'e_total': -195.97164202433785, 'fci': -195.9733280486993}

# %%
from matplotlib import pyplot as plt

R_range = np.arange(1, 3.01, 0.1)
fci_energies = []
for R in R_range:
    json_path = Path(f'data/chemistry/f2_R{R:.1f}_angstrom_sto-3g_12q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))
    fci_energies.append(float(data['fci_energy']))
R_values = [item['R'] for item in energy_ucc]
estimated_energies_ucc = [item['e_total'] for item in energy_ucc]

plt.figure(figsize=(10, 6))
plt.scatter(R_values, estimated_energies_ucc, marker='s', label='UCC-style Ansatz (VQE)')
plt.plot(R_range, fci_energies, 'k-', label='FCI Energy')
plt.xlabel('Interatomic Distance R (angstrom)')
plt.ylabel('Energy (Hartree)')
plt.title('F2 Molecule Energy vs Interatomic Distance')
plt.legend()
plt.tick_params(right=True, top=True)
plt.grid(alpha=0.25)
plt.tight_layout()
plt.show()
