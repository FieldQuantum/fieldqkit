# %% [markdown]
# # F2 12Q VQE: Circuit Compression Demo
#
# This notebook demonstrates VQE under `gradient_method="parameter-shift"` with hybrid MPS/MPO circuit compression.
#
# Comparison items:
# - Baseline: no compression
# - Compression: suffix block planning + local recompression

# %%
# from __future__ import annotations

import os
import json
import math
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.algorithms.circuit_compression import plan_hybrid_suffix_blocks
from quantum_hw.circuit import QuantumCircuit

# %%
# ===== 1) Load F2 12-qubit Hamiltonian =====
json_path = Path('data/chemistry/f2_R2.6_angstrom_sto-3g_12q.json')
data = json.loads(json_path.read_text(encoding='utf-8'))

f2_constant = float(data['constant'])
f2_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded:', json_path)
print('nqubits =', nqubits, 'term_count =', len(f2_6q_terms))
print('fci_energy =', fci_energy)
# Out:
# Loaded: data\chemistry\f2_R2.6_angstrom_sto-3g_12q.json
# nqubits = 12 term_count = 382
# fci_energy = -195.9734686096283

# %%
# ===== 2) Build the same LiH custom ansatz style used in existing demo =====
def build_f2_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(12)

    # HF state or "singlet" reference state
    qc.ry("theta_0", 8)
    qc.cx(8, 9)
    qc.cx(9, 10)
    qc.cx(10, 11)

    for q in range(10):
        qc.x(q)

    qc.pauli_evolution("theta_1", "Y0 X1 Z2 Z3 Z4 Z5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_2", "Y2 X3 Z4 Z5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_3", "Y4 X5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_4", "Y6 X7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_5", "Y8 X9 X10 Y11")

    return qc


custom_ansatz_qc = build_f2_symbolic_ansatz()
symbolic_params = sorted([
    k for k, v in custom_ansatz_qc.params_value.items()
    if isinstance(k, str) and isinstance(v, str)
])

print('custom gate count =', len(custom_ansatz_qc.gates))
print('symbolic params =', symbolic_params)
# Out:
# custom gate count = 149
# symbolic params = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5']

# %%
# ===== 3) Shared VQE config (parameter-shift) =====
cfg = {
    'layers': 3,
    'shots': 1024,
    'max_iters': 20,
    'learning_rate': 0.1,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2.0,
}

base_kwargs = {
    'name': 'f2_12q_custom_compress_demo',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': f2_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01] * len(symbolic_params),
}

print(cfg)
# Out:
# {'layers': 3, 'shots': 1024, 'max_iters': 20, 'learning_rate': 0.1, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %%
# ===== 4) Baseline run: no compression =====
runner_base = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
    enable_circuit_compression=False,
)

res_base = runner_base.run_model(**base_kwargs)
e_total_base = f2_constant + res_base.best_energy
err_base = abs(e_total_base - fci_energy)

print('Baseline best_total =', round(e_total_base, 8))
print('Baseline abs_error_vs_fci =', round(err_base, 8))
# Out:
# [vqe] prepare run: name=f2_12q_custom_compress_demo num_qubits=12 model=custom layers=3 shots=1024 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=6 ansatz=custom shots=1024 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-5.620472 grad_norm=0.392761
# [vqe] iter 0 new best energy=-5.620472
# [vqe] iter 1 start
# [vqe] iter 1 energy=-5.654690 grad_norm=0.387943
# [vqe] iter 1 new best energy=-5.654690
# [vqe] iter 2 start
# [vqe] iter 2 energy=-5.697846 grad_norm=0.381258
# [vqe] iter 2 new best energy=-5.697846
# [vqe] iter 3 start
# [vqe] iter 3 energy=-5.734263 grad_norm=0.369368
# [vqe] iter 3 new best energy=-5.734263
# [vqe] iter 4 start
# [vqe] iter 4 energy=-5.768479 grad_norm=0.354162
# [vqe] iter 4 new best energy=-5.768479
# [vqe] iter 5 start
# [vqe] iter 5 energy=-5.804712 grad_norm=0.336466
# [vqe] iter 5 new best energy=-5.804712
# [vqe] iter 6 start
# [vqe] iter 6 energy=-5.838585 grad_norm=0.314591
# [vqe] iter 6 new best energy=-5.838585
# [vqe] iter 7 start
# [vqe] iter 7 energy=-5.866764 grad_norm=0.291052
# [vqe] iter 7 new best energy=-5.866764
# [vqe] iter 8 start
# [vqe] iter 8 energy=-5.892833 grad_norm=0.266197
# [vqe] iter 8 new best energy=-5.892833
# [vqe] iter 9 start
# [vqe] iter 9 energy=-5.918523 grad_norm=0.234943
# [vqe] iter 9 new best energy=-5.918523
# [vqe] iter 10 start
# [vqe] iter 10 energy=-5.939775 grad_norm=0.202795
# [vqe] iter 10 new best energy=-5.939775
# [vqe] iter 11 start
# [vqe] iter 11 energy=-5.955328 grad_norm=0.179317
# [vqe] iter 11 new best energy=-5.955328
# [vqe] iter 12 start
# [vqe] iter 12 energy=-5.969636 grad_norm=0.147857
# [vqe] iter 12 new best energy=-5.969636
# [vqe] iter 13 start
# [vqe] iter 13 energy=-5.981678 grad_norm=0.105119
# [vqe] iter 13 new best energy=-5.981678
# [vqe] iter 14 start
# [vqe] iter 14 energy=-5.988119 grad_norm=0.088681
# [vqe] iter 14 new best energy=-5.988119
# [vqe] iter 15 start
# [vqe] iter 15 energy=-5.992096 grad_norm=0.078481
# [vqe] iter 15 new best energy=-5.992096
# [vqe] iter 16 start
# [vqe] iter 16 energy=-5.995506 grad_norm=0.028084
# [vqe] iter 16 new best energy=-5.995506
# [vqe] iter 17 start
# [vqe] iter 17 energy=-5.995203 grad_norm=0.042236
# [vqe] iter 18 start
# [vqe] iter 18 energy=-5.992819 grad_norm=0.076759
# [vqe] iter 19 start
# [vqe] iter 19 energy=-5.991258 grad_norm=0.066585
# Baseline best_total = -195.97203031
# Baseline abs_error_vs_fci = 0.0014383

# %%
# ===== 5) Compression run: enable planner + compression =====
cfg['gradient_method'] = "parameter-shift"
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
    enable_circuit_compression=True,
    compression_block_layers=6,
)

res_cmp = runner_cmp.run_model(**base_kwargs)
e_total_cmp = f2_constant + res_cmp.best_energy
err_cmp = abs(e_total_cmp - fci_energy)

print('Compressed best_total =', round(e_total_cmp, 8))
print('Compressed abs_error_vs_fci =', round(err_cmp, 8))
# Out:
# [vqe] prepare run: name=f2_12q_custom_compress_demo num_qubits=12 model=custom layers=3 shots=1024 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=6 ansatz=custom shots=1024 shift=1.5707963267948966 gradient=parameter-shift
# [vqe] iter 0 start

# %%
# ===== 6) Compare convergence curves =====
plt.figure(figsize=(7, 4))
plt.plot(np.array(res_base.energy_history) + f2_constant, marker='o', ms=3, label='baseline')
plt.plot(np.array(res_cmp.energy_history) + f2_constant, marker='s', ms=3, label='compressed')
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI')
plt.xlabel('Iteration')
plt.ylabel('Total Energy (Hartree)')
plt.title('F2 12Q VQE: baseline vs compression')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

print('--- Summary ---')
print('Baseline total energy   :', round(e_total_base, 8))
print('Compressed total energy :', round(e_total_cmp, 8))
print('Baseline |E-FCI|        :', round(err_base, 8))
print('Compressed |E-FCI|      :', round(err_cmp, 8))
# Out:
# --- Summary ---
# Baseline total energy   : -7.83609882
# Compressed total energy : -7.83523198
# Baseline |E-FCI|        : 0.0095848
# Compressed |E-FCI|      : 0.01045164

# %%
# ===== 7) Run experiments =====
cfg['prefer_chips'] = 'Simulator'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    clifford_fitting=cfg['clifford_fitting'],
    clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
    enable_circuit_compression=True,
    compression_block_layers=[5],
)

exp_kwargs = {
    'name': 'lih_6q_custom_compress_demo',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01] * len(symbolic_params),
}

res_cmp = runner_cmp.run_model(**exp_kwargs)
e_total_cmp = lih_constant + res_cmp.best_energy
err_cmp = abs(e_total_cmp - fci_energy)

print('=== 6-Qubit LiH VQE Result ===')
print('Compressed best_total =', round(e_total_cmp, 8))
print('Compressed abs_error_vs_fci =', round(err_cmp, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res_cmp.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'LiH VQE Convergence (R=2.2)')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=lih_6q_custom_compress_demo num_qubits=6 model=custom layers=3 shots=1024 max_iters=6
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=6 layers=3 params=4 ansatz=custom shots=1024 shift=1.5707963267948966 gradient=parameter-shift
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.645809 grad_norm=0.163371
# [vqe] iter 0 new best energy=-0.645809
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.651576 grad_norm=0.138912
# [vqe] iter 1 new best energy=-0.651576
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.669804 grad_norm=0.105873
# [vqe] iter 2 new best energy=-0.669804
# [vqe] iter 3 start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 35
#       7 runner_cmp = VQERunner(
#       8     client=QuantumHardwareClient(),
#       9     layers=cfg['layers'],
#    (...)     21     compression_block_layers=[5],
#      22 )
#      24 exp_kwargs = {
#      25     'name': 'lih_6q_custom_compress_demo',
#      26     'num_qubits': nqubits,
#    (...)     32     'init_params': [0.01] * len(symbolic_params),
#      33 }
# ---> 35 res_cmp = runner_cmp.run_model(**exp_kwargs)
#      36 e_total_cmp = lih_constant + res_cmp.best_energy
#      37 err_cmp = abs(e_total_cmp - fci_energy)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:1160, in VQERunner.run_model(self, name, num_qubits, model, model_params, hamiltonian, target_qubits, init_params, callback, prefer_chips, rank_weights, ansatz, custom_ansatz_circuit)
#    1158 try:
#    1159     print("[vqe] running on chip:", chip_name)
# -> 1160     return run_vqe_with_backend(
#    1161         self.client,
#    1162         name=name,
#    1163         num_qubits=num_qubits,
#    1164         backend=backend,
#    1165         chip_name=chip_name,
#    1166         hamiltonian=hamiltonian,
#    1167         layers=self.layers,
#    1168         shots=self.shots,
#    1169         max_iters=self.max_iters,
#    1170         learning_rate=self.learning_rate,
#    1171         beta1=self.beta1,
#    1172         beta2=self.beta2,
#    1173         eps=self.eps,
#    1174         shift=self.shift,
#    1175         zne=self.zne,
#    1176         readout_mitigation=self.readout_mitigation,
#    1177         target_qubits=target_qubits,
#    1178         seed=self.seed,
#    1179         init_params=init_params,
#    1180         callback=callback,
#    1181         gradient_method=self.gradient_method,
#    1182         ansatz=ansatz,
#    1183         custom_ansatz_circuit=custom_ansatz_circuit,
#    1184         clifford_fitting=self.clifford_fitting,
#    1185         clifford_fitting_num_samples=self.clifford_fitting_num_samples,
#    1186         clifford_fitting_num_non_clifford_gates=self.clifford_fitting_num_non_clifford_gates,
#    1187         enable_block_planner=self.enable_block_planner,
#    1188         planner_bond_cap=self.planner_bond_cap,
#    1189         planner_trunc_tol=self.planner_trunc_tol,
#    1190         planner_max_layers_per_block=self.planner_max_layers_per_block,
#    1191         enable_circuit_compression=self.enable_circuit_compression,
#    1192         compression_block_layers=self.compression_block_layers,
#    1193         compression_optimizer_steps=self.compression_optimizer_steps,
#    1194         compression_optimizer_lr=self.compression_optimizer_lr,
#    1195         compression_verbose=self.compression_verbose,
#    1196         compression_plot_loss=self.compression_plot_loss,
#    1197     )
#    1198 except Exception as exc:
#    1199     last_error = exc
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:1012, in run_vqe_with_backend(client, name, num_qubits, backend, chip_name, hamiltonian, layers, shots, max_iters, learning_rate, beta1, beta2, eps, shift, zne, readout_mitigation, target_qubits, seed, init_params, callback, gradient_method, ansatz, custom_ansatz_circuit, clifford_fitting, clifford_fitting_num_samples, clifford_fitting_num_non_clifford_gates, enable_block_planner, planner_bond_cap, planner_trunc_tol, planner_max_layers_per_block, enable_circuit_compression, compression_block_layers, compression_optimizer_steps, compression_optimizer_lr, compression_verbose, compression_plot_loss)
#     997     qc = _maybe_compress_qc(qc, None)
#     998     energy, expectations = _evaluate_energy_with_backend(
#     999         client,
#    1000         qc,
#    (...)   1010         target_qubits=target_qubits_in_use,
#    1011     )
# -> 1012     grads = _parameter_shift_gradient(
#    1013         client,
#    1014         params,
#    1015         name=f"{name}_iter{it}",
#    1016         num_qubits=num_qubits,
#    1017         backend=backend,
#    1018         chip_name=chip_name,
#    1019         shots=shots,
#    1020         hamiltonian=hamiltonian,
#    1021         shift=shift,
#    1022         zne=zne,
#    1023         readout_mitigation=readout_mitigation,
#    1024         transpiled_template=transpiled_template,
#    1025         param_names=param_names,
#    1026         clifford_fit_map=clifford_fit_map,
#    1027         target_qubits=target_qubits_in_use,
#    1028         circuit_transform=_maybe_compress_qc if enable_circuit_compression else None,
#    1029     )
#    1031 grad_norm = float(np.linalg.norm(grads))
#    1032 print(f"[vqe] iter {it} energy={energy:.6f} grad_norm={grad_norm:.6f}")
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:578, in _parameter_shift_gradient(client, params, name, num_qubits, backend, chip_name, shots, hamiltonian, shift, zne, readout_mitigation, transpiled_template, param_names, clifford_fit_map, target_qubits, circuit_transform)
#     576 qc_minus = _instantiate_transpiled_template(transpiled_template, param_names, params_minus)
#     577 if circuit_transform is not None:
# --> 578     qc_plus = circuit_transform(qc_plus, i)
#     579     qc_minus = circuit_transform(qc_minus, i)
#     581 e_plus, _ = _evaluate_energy_with_backend(
#     582     client,
#     583     qc_plus,
#    (...)    593     target_qubits=target_qubits,
#     594 )
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:855, in run_vqe_with_backend.<locals>._maybe_compress_qc(qc_bound, changed_param_index)
#     852         local_warm_start = compression_warm_start
#     853     call_tag = f"shift(param={int(changed_param_index)}, block={int(block_id)})"
# --> 855 compressed_qc, next_warm_start, summary = compress_circuit_with_hybrid_objective(
#     856     qc_bound,
#     857     num_qubits=num_qubits,
#     858     approx_layers=approx_depth,
#     859     optimizer_steps=int(local_steps),
#     860     optimizer_lr=float(compression_optimizer_lr),
#     861     use_mpo_for_deep_suffix=True,
#     862     plan=plan,
#     863     bond_cap=int(unified_bond_cap),
#     864     state_objective_weight=1.0,
#     865     process_objective_weight=0.25,
#     866     warm_start_params=local_warm_start,
#     867     trainable_param_mask=trainable_mask,
#     868 )
#     869 compression_warm_start = next_warm_start
#     870 if changed_param_index is None:
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\circuit_compression.py:501, in compress_circuit_with_hybrid_objective(qc_bound, num_qubits, approx_layers, optimizer_steps, optimizer_lr, use_mpo_for_deep_suffix, plan, bond_cap, state_objective_weight, process_objective_weight, warm_start_params, trainable_param_mask, device)
#     498 full_params_t[active_idx] = active_t
#     499 loss = _objective_from_full_params(full_params_t)
# --> 501 loss.backward()
#     502 optimizer.step()
#     504 cur = float(loss.detach().cpu().item())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\autograd\__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\autograd\graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\autograd\function.py:317, in BackwardCFunction.apply(self, *args)
#     311     raise RuntimeError(
#     312         "Implementing both 'backward' and 'vjp' for a custom "
#     313         "Function is not allowed. You should only implement one "
#     314         "of them."
#     315     )
#     316 user_fn = vjp_fn if vjp_fn is not Function.vjp else backward_fn
# --> 317 return user_fn(self, *args)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\sim\mps.py:50, in ComplexSVD.backward(ctx, grad_u, grad_s, grad_vh)
#      48 # Build singular value matrices and safe inverse.
#      49 s_mat = torch.diag_embed(s.to(dtype=complex_dtype))
# ---> 50 s_inv = torch.where(torch.abs(s_mat) > 1e-12, 1.0 / s_mat, torch.zeros_like(s_mat))
#      52 # Denominator for anti-Hermitian projection terms.
#      53 f = s.unsqueeze(-2) ** 2 - s.unsqueeze(-1) ** 2
#
# KeyboardInterrupt:
