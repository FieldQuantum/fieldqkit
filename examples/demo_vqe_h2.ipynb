# %% [markdown]
# # H2 分子 VQE 完整教程（4-Qubit）
#
# 本教程面向首次使用者，目标是在同一份 notebook 中完成：
# - 从量子化学模型得到 H2 的 4-qubit 哈密顿量
# - 构建一个 H2 专用的 UCC-style 参数化电路
# - 使用 VQE 进行参数优化并与 FCI 基准比较
# - 对照三种 ansatz：`hardwareefficient`、`ucc`、`custom`
#
# ---
#
# ## 理论背景（从分子到量子线路）
#
# 电子哈密顿量（二次量子化）为：
#
# $$
# \hat H = \sum_{pq} h_{pq} a_p^\dagger a_q + \frac{1}{2}\sum_{pqrs} h_{pqrs} a_p^\dagger a_q^\dagger a_r a_s
# $$
#
# 将其映射到 qubit 空间后，得到 Pauli 算符线性组合：
#
# $$
# \hat H_q = c_0 I + \sum_{k} c_k P_k,\quad P_k \in \{I,X,Y,Z\}^{\otimes n}
# $$
#
# VQE 的优化目标是最小化：
#
# $$
# E(\theta) = \langle \psi(\theta) | \hat H_q | \psi(\theta) \rangle
# $$
#
# 将上式代入 Pauli 分解可得：
#
# $$
# E(\theta)=c_0+\sum_k c_k\langle \psi(\theta)|P_k|\psi(\theta)\rangle
# $$
#
# 这说明 VQE 的数值任务可分解为两步：
# 1. 准备参数化态 $|\psi(\theta)\rangle$。
# 2. 估计每个 Pauli 项期望值并按系数加权求和。
#
# 当 ansatz 足够表达基态且优化收敛时，估计能量应接近 FCI 参考值。

# %% [markdown]
# ## 1. 参数配置与运行建议
#
# 本单元配置几何、化学与优化超参数。
#
# ### 关键参数说明
# - `R` 与 `R_UNIT`：H-H 键长及单位。
# - `BASIS`：基组（示例用 `sto-3g`）。
# - `layers`：ansatz 层数。
# - `gradient_method`：推荐在模拟器使用 `autograd` 进行快速验证。
#
# ### 运行建议
# 1. 首次跑通优先保持 `prefer_chips='Simulator'`。
# 2. 若后续切换硬件，可考虑改用 `parameter-shift`。
# 3. 层数与迭代次数增加会提高表达能力，但计算成本也会上升。

# %%
from pathlib import Path
import json
import math

# Geometry / chemistry config
R = 2.6
R_UNIT = 'angstrom'
BASIS = 'sto-3g'
MULTIPLICITY = 1
CHARGE = 0

# VQE config
cfg = {
    'layers': 1,
    'shots': 4096,
    'max_iters': 20,
    'learning_rate': 0.1,
    'seed': 7,
    'gradient_method': 'parameter-shift',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 8,
}

print('R =', R, R_UNIT)
print('Basis =', BASIS)
print('VQE cfg =', cfg)
# Out:
# R = 2.6 angstrom
# Basis = sto-3g
# VQE cfg = {'layers': 1, 'shots': 4096, 'max_iters': 20, 'learning_rate': 0.1, 'seed': 7, 'gradient_method': 'parameter-shift', 'prefer_chips': 'Simulator', 'shift': 0.39269908169872414}

# %% [markdown]
# ## 2. 读取 WSL 导出的 4-qubit 哈密顿量系数
#
# For the H₂ molecule in the **STO-3G basis**, there are **4 spin orbitals**, which map to **4 qubits** after fermion-to-qubit transformation (e.g., Jordan–Wigner).
#
# Qubit ordering (one common convention):
#
# | Qubit | Spin Orbital |
# |------|--------------|
# | q0 | 0↑ |
# | q1 | 0↓ |
# | q2 | 1↑ |
# | q3 | 1↓ |
#
# 默认读取文件：
# - `data/chemistry/h2_R2.6_sto-3g.json`
#
# 若文件不存在，请在 WSL 中执行：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_h2.sh 2.6 angstrom
# ```
#
# 读取后可获得：
# - `h2_constant`
# - `h2_4q_terms`
# - `nqubits`
# - `fci_energy`

# %%
from __future__ import annotations

import json
from pathlib import Path

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner

json_path = Path('data/chemistry/h2_R2.6_angstrom_sto-3g.json')
if not json_path.exists():
    raise FileNotFoundError(
        f'Missing {json_path}. Generate it in WSL with:\n'
        'python scripts/export_h2_terms_wsl.py --R 2.6 --unit angstrom '
        '--output data/chemistry/h2_R2.6_angstrom_sto-3g.json'
    )

data = json.loads(json_path.read_text(encoding='utf-8'))

h2_constant = float(data['constant'])
h2_4q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded from:', json_path)
print('nqubits:', nqubits)
print('term_count:', len(h2_4q_terms))
print('fci_energy:', fci_energy)
# Out:
# Loaded from: data\chemistry\h2_R2.6_angstrom_sto-3g.json
# nqubits: 4
# term_count: 14
# fci_energy: -0.9351960308474745

# %% [markdown]
# ## 3. 在 4-qubit 哈密顿量上运行 VQE，并与 FCI 对照
#
# 该单元将：
# - 使用上一步自动生成的 `h2_4q_terms`
# - 在 `num_qubits = 4` 上运行你的框架 VQE（使用默认hardware-efficient ansatz）
# - 计算总能量 `E_total = h2_constant + E_nonconst`
# - 与 `fci_energy` 做误差对比（可验证）

# %%
client = QuantumHardwareClient()
runner = VQERunner(
    client=client,
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
)

result = runner.run_model(
    name='h2_4q_demo_notebook',
    num_qubits=nqubits,
    model='custom',
    hamiltonian=h2_4q_terms,
    prefer_chips=cfg['prefer_chips'],
)

best_total_energy = h2_constant + result.best_energy
abs_error_fci = abs(best_total_energy - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(best_total_energy, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(result.energy_history) + h2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_demo_notebook num_qubits=4 model=custom layers=1 shots=4096 max_iters=50
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=50 layers=1 params=16 ansatz=hardwareefficient shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=0.097025 grad_norm=0.275339
# [vqe] iter 0 new best energy=0.097025
# [vqe] iter 1 start
# [vqe] iter 1 energy=0.053946 grad_norm=0.261074
# [vqe] iter 1 new best energy=0.053946
# [vqe] iter 2 start
# [vqe] iter 2 energy=0.013214 grad_norm=0.244715
# [vqe] iter 2 new best energy=0.013214
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.023879 grad_norm=0.225821
# [vqe] iter 3 new best energy=-0.023879
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.056340 grad_norm=0.204189
# [vqe] iter 4 new best energy=-0.056340
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.083852 grad_norm=0.180217
# [vqe] iter 5 new best energy=-0.083852
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.106521 grad_norm=0.154481
# [vqe] iter 6 new best energy=-0.106521
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.124423 grad_norm=0.128632
# [vqe] iter 7 new best energy=-0.124423
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.137692 grad_norm=0.106084
# [vqe] iter 8 new best energy=-0.137692
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.146796 grad_norm=0.090880
# [vqe] iter 9 new best energy=-0.146796
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.152577 grad_norm=0.084843
# [vqe] iter 10 new best energy=-0.152577
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.156062 grad_norm=0.085652
# [vqe] iter 11 new best energy=-0.156062
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.158222 grad_norm=0.089159
# [vqe] iter 12 new best energy=-0.158222
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.159828 grad_norm=0.092453
# [vqe] iter 13 new best energy=-0.159828
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.161405 grad_norm=0.094397
# [vqe] iter 14 new best energy=-0.161405
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.163224 grad_norm=0.095032
# [vqe] iter 15 new best energy=-0.163224
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.165359 grad_norm=0.094955
# [vqe] iter 16 new best energy=-0.165359
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.167783 grad_norm=0.094867
# [vqe] iter 17 new best energy=-0.167783
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.170467 grad_norm=0.095282
# [vqe] iter 18 new best energy=-0.170467
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.173444 grad_norm=0.096420
# [vqe] iter 19 new best energy=-0.173444
# [vqe] iter 20 start
# [vqe] iter 20 energy=-0.176813 grad_norm=0.098266
# [vqe] iter 20 new best energy=-0.176813
# [vqe] iter 21 start
# [vqe] iter 21 energy=-0.180727 grad_norm=0.100698
# [vqe] iter 21 new best energy=-0.180727
# [vqe] iter 22 start
# [vqe] iter 22 energy=-0.185366 grad_norm=0.103598
# [vqe] iter 22 new best energy=-0.185366
# [vqe] iter 23 start
# [vqe] iter 23 energy=-0.190918 grad_norm=0.106900
# [vqe] iter 23 new best energy=-0.190918
# [vqe] iter 24 start
# [vqe] iter 24 energy=-0.197543 grad_norm=0.110579
# [vqe] iter 24 new best energy=-0.197543
# [vqe] iter 25 start
# [vqe] iter 25 energy=-0.205346 grad_norm=0.114605
# [vqe] iter 25 new best energy=-0.205346
# [vqe] iter 26 start
# [vqe] iter 26 energy=-0.214372 grad_norm=0.118868
# [vqe] iter 26 new best energy=-0.214372
# [vqe] iter 27 start
# [vqe] iter 27 energy=-0.224596 grad_norm=0.123135
# [vqe] iter 27 new best energy=-0.224596
# [vqe] iter 28 start
# [vqe] iter 28 energy=-0.235916 grad_norm=0.127045
# [vqe] iter 28 new best energy=-0.235916
# [vqe] iter 29 start
# [vqe] iter 29 energy=-0.248148 grad_norm=0.130164
# [vqe] iter 29 new best energy=-0.248148
# [vqe] iter 30 start
# [vqe] iter 30 energy=-0.261027 grad_norm=0.132060
# [vqe] iter 30 new best energy=-0.261027
# [vqe] iter 31 start
# [vqe] iter 31 energy=-0.274215 grad_norm=0.132406
# [vqe] iter 31 new best energy=-0.274215
# [vqe] iter 32 start
# [vqe] iter 32 energy=-0.287330 grad_norm=0.131049
# [vqe] iter 32 new best energy=-0.287330
# [vqe] iter 33 start
# [vqe] iter 33 energy=-0.300000 grad_norm=0.128053
# [vqe] iter 33 new best energy=-0.300000
# [vqe] iter 34 start
# [vqe] iter 34 energy=-0.311934 grad_norm=0.123665
# [vqe] iter 34 new best energy=-0.311934
# [vqe] iter 35 start
# [vqe] iter 35 energy=-0.322956 grad_norm=0.118229
# [vqe] iter 35 new best energy=-0.322956
# [vqe] iter 36 start
# [vqe] iter 36 energy=-0.332994 grad_norm=0.112091
# [vqe] iter 36 new best energy=-0.332994
# [vqe] iter 37 start
# [vqe] iter 37 energy=-0.342052 grad_norm=0.105487
# [vqe] iter 37 new best energy=-0.342052
# [vqe] iter 38 start
# [vqe] iter 38 energy=-0.350180 grad_norm=0.098463
# [vqe] iter 38 new best energy=-0.350180
# [vqe] iter 39 start
# [vqe] iter 39 energy=-0.357452 grad_norm=0.090877
# [vqe] iter 39 new best energy=-0.357452
# [vqe] iter 40 start
# [vqe] iter 40 energy=-0.363901 grad_norm=0.082548
# [vqe] iter 40 new best energy=-0.363901
# [vqe] iter 41 start
# [vqe] iter 41 energy=-0.369489 grad_norm=0.073483
# [vqe] iter 41 new best energy=-0.369489
# [vqe] iter 42 start
# [vqe] iter 42 energy=-0.374118 grad_norm=0.064095
# [vqe] iter 42 new best energy=-0.374118
# [vqe] iter 43 start
# [vqe] iter 43 energy=-0.377680 grad_norm=0.055336
# [vqe] iter 43 new best energy=-0.377680
# [vqe] iter 44 start
# [vqe] iter 44 energy=-0.380130 grad_norm=0.048642
# [vqe] iter 44 new best energy=-0.380130
# [vqe] iter 45 start
# [vqe] iter 45 energy=-0.381547 grad_norm=0.045333
# [vqe] iter 45 new best energy=-0.381547
# [vqe] iter 46 start
# [vqe] iter 46 energy=-0.382144 grad_norm=0.045505
# [vqe] iter 46 new best energy=-0.382144
# [vqe] iter 47 start
# [vqe] iter 47 energy=-0.382227 grad_norm=0.047726
# [vqe] iter 47 new best energy=-0.382227
# [vqe] iter 48 start
# [vqe] iter 48 energy=-0.382106 grad_norm=0.050175
# [vqe] iter 49 start
# [vqe] iter 49 energy=-0.382015 grad_norm=0.051601
# === 4-Qubit H2 VQE Result ===
# Estimated total energy:   -0.92650152
# FCI reference energy:     -0.93519603
# Absolute error vs FCI:    0.00869451

# %% [markdown]
# ## 4. 构建 H2 专用 UCC-style Custom Ansatz
#
# 这一步我们手工定义一个“面向 H2 的”参数化电路模板，并交给 `custom` 接口优化。
#
# ### 设计思想
# - 参考态：先准备 Hartree-Fock (HF) 占据态（示例 `|1100>`，与映射约定相关）。
# - 单激发（singles-like）：在占据轨道与虚轨道之间加入参数化混合。
# - 双激发（doubles-like）：加入相关激发近似块，增强电子关联表达能力。
#
# ### The **Unitary Coupled Cluster (UCC)** ansatz is
#
# $$
# U(\theta) = e^{T - T^\dagger}
# $$
# where
#
# $$
# T = T_1 + T_2
# $$
#
# - $T_1$: single excitations
# - $T_2$: double excitations
#
# For the H₂ system, the most important contribution is the **double excitation**
#
# $$
# a_3^\dagger a_2^\dagger a_1 a_0
# $$
#
# Thus the ansatz becomes
#
# $$
# U(\theta) =
# \exp\Big[
# \theta(
# a_3^\dagger a_2^\dagger a_1 a_0
# -
# a_0^\dagger a_1^\dagger a_2 a_3
# )
# \Big]
# $$
#
# ### Pauli Representation
#
# After the **Jordan–Wigner transformation**, the double excitation operator maps to a sum of Pauli strings:
#
# $$
# U(\theta) =
# \exp\left[
# -\frac{i\theta}{8}
# (
# Y_0 X_1 X_2 X_3
# +
# X_0 Y_1 X_2 X_3
# -
# X_0 X_1 Y_2 X_3
# -
# X_0 X_1 X_2 Y_3
# )
# \right]
# $$
#
# Therefore the unitary can be implemented as four Pauli rotations.
#
# ### Circuit Structure
#
# Each Pauli exponential $e^{-i\phi P}$ is implemented with the standard pattern:
#
# 1. **Basis change** (convert X/Y to Z basis)
# 2. **CNOT ladder** to collect parity
# 3. **RZ rotation**
# 4. **Undo CNOT ladder**
# 5. **Undo basis change**

# %%
from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.circuit import QuantumCircuit

def build_h2_ucc_style_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(4)

    # -------------------------
    # Hartree–Fock reference
    # |1100>
    # -------------------------

    qc.x(0)
    qc.x(1)

    # -------------------------------------------------
    # term1: exp[-i θ/8 Y0 X1 X2 X3]
    # -------------------------------------------------

    qc.rx(np.pi/2,0)
    qc.h(1)
    qc.h(2)
    qc.h(3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("theta",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.rx(-np.pi/2,0)
    qc.h(1)
    qc.h(2)
    qc.h(3)


    # -------------------------------------------------
    # term2: exp[-i θ/8 X0 Y1 X2 X3]
    # -------------------------------------------------

    qc.h(0)
    qc.rx(np.pi/2,1)
    qc.h(2)
    qc.h(3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("theta",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.h(0)
    qc.rx(-np.pi/2,1)
    qc.h(2)
    qc.h(3)


    # -------------------------------------------------
    # term3: exp[+i θ/8 X0 X1 Y2 X3]
    # -------------------------------------------------

    qc.h(0)
    qc.h(1)
    qc.rx(np.pi/2,2)
    qc.h(3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("-theta",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.h(0)
    qc.h(1)
    qc.rx(-np.pi/2,2)
    qc.h(3)


    # -------------------------------------------------
    # term4: exp[+i θ/8 X0 X1 X2 Y3]
    # -------------------------------------------------

    qc.h(0)
    qc.h(1)
    qc.h(2)
    qc.rx(np.pi/2,3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("-theta",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.h(0)
    qc.h(1)
    qc.h(2)
    qc.rx(-np.pi/2,3)

    return qc

custom_ansatz_qc = build_h2_ucc_style_symbolic_ansatz()
symbolic_params = sorted(
    [k for k, v in custom_ansatz_qc.params_value.items() if isinstance(k, str) and isinstance(v, str)]
)
print('Total gates in custom H2-UCC-style ansatz:', len(custom_ansatz_qc.gates))
# Out:
# Total gates in custom H2-UCC-style ansatz: 62

# %% [markdown]
# ## 6. 运行 VQE 并对照两种 Ansatz
#
# 在同一哈密顿量上分别运行：
# - `hardwareefficient`：硬件友好、通用性强。
# - `custom`：本教程构建的 H2 专用 UCC-style 模板。
#
# ### 结果解读方法
# - `best_total = h2_constant + best_nonconst`：估计总能量。
# - `abs_err_fci = |best_total - fci_energy|`：相对 FCI 的误差。
# - 收敛曲线：观察优化稳定性与下降速度。
#
# 通常来说，加入更强问题结构先验的 ansatz，往往在相同预算下能得到更低误差，但并不绝对。

# %%
def run_vqe_with_selected_ansatz(ansatz_name: str, custom_qc=None):
    runner_cmp = VQERunner(
        client=QuantumHardwareClient(),
        layers=cfg['layers'],
        shots=cfg['shots'],
        max_iters=cfg['max_iters'],
        learning_rate=cfg['learning_rate'],
        gradient_method=cfg['gradient_method'],
        seed=cfg['seed'],
        shift=cfg['shift'],
    )

    kwargs = {
        'name': f'h2_4q_cmp_{ansatz_name}',
        'num_qubits': nqubits,
        'model': 'custom',
        'hamiltonian': h2_4q_terms,
        'ansatz': ansatz_name,
        'prefer_chips': cfg['prefer_chips'],
    }
    if ansatz_name == 'custom':
        kwargs['custom_ansatz_circuit'] = custom_qc

    res = runner_cmp.run_model(**kwargs)
    e_total = h2_constant + res.best_energy
    return {
        'ansatz': ansatz_name,
        'best_nonconst': float(res.best_energy),
        'best_param': res.best_params,
        'best_total': float(e_total),
        'abs_err_fci': float(abs(e_total - fci_energy)),
        'history': res.energy_history,
    }

compare_rows = [
    run_vqe_with_selected_ansatz('custom', custom_qc=custom_ansatz_qc),
    # run_vqe_with_selected_ansatz('hardwareefficient'),
]

print('=== Ansatz Comparison on H2 4Q ===')
for row in compare_rows:
    print(
        row['ansatz'],
        '| best_total =', round(row['best_total'], 8),
        '| abs_err_fci =', round(row['abs_err_fci'], 8),
        '| best_param =', row['best_param'],
    )

plt.figure(figsize=(7, 4))
for row in compare_rows:
    plt.plot(np.array(row['history']) + h2_constant, marker='o', ms=3, label=row['ansatz'])
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Ansatz Comparison (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_cmp_custom num_qubits=4 model=custom layers=1 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=1 params=1 ansatz=custom shots=4096 shift=0.39269908169872414 gradient=parameter-shift
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.054068 grad_norm=0.285927
# [vqe] iter 0 new best energy=-0.054068
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.171593 grad_norm=0.280160
# [vqe] iter 1 new best energy=-0.171593
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.278180 grad_norm=0.237717
# [vqe] iter 2 new best energy=-0.278180
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.348539 grad_norm=0.149708
# [vqe] iter 3 new best energy=-0.348539
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.386558 grad_norm=0.044153
# [vqe] iter 4 new best energy=-0.386558
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.383165 grad_norm=0.054917
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.362274 grad_norm=0.132684
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.339444 grad_norm=0.176414
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.324664 grad_norm=0.192295
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.324616 grad_norm=0.192435
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.336372 grad_norm=0.180521
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.351211 grad_norm=0.155862
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.368316 grad_norm=0.116793
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.380668 grad_norm=0.071760
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.388176 grad_norm=0.022584
# [vqe] iter 14 new best energy=-0.388176
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.387973 grad_norm=0.022861
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.382422 grad_norm=0.063537
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.373924 grad_norm=0.092843
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.367199 grad_norm=0.110220
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.364664 grad_norm=0.116480
# === Ansatz Comparison on H2 4Q ===
# custom | best_total = -0.93244972 | abs_err_fci = 0.00274631 | best_param = [3.5147517552528167]

# %% [markdown]
# ## 7. 在真实硬件上运行线路

# %%
cfg['prefer_chips'] = 'Baihua'
cfg['zne'] = False
cfg['readout_mitigation'] = False
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 20

runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    clifford_fitting=cfg['clifford_fitting'],
    clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
)

kwargs = {
    'name': f'h2_4q_cmp_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': h2_4q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
}

res = runner_cmp.run_model(**kwargs)
e_total = h2_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + h2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_cmp_custom num_qubits=4 model=custom layers=1 shots=4096 max_iters=20
# Baihua configuration loading done!
# The last calibration time was 2026-03-11 13:37:52
# [vqe] candidate chips: ['Baihua']
# Baihua configuration loading done!
# The last calibration time was 2026-03-11 13:37:52
# [vqe] running on chip: Baihua
