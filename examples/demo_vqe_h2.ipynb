# %% [markdown]
# # H2 分子 VQE 完整教程（4-Qubit）
#
# 本教程面向首次使用者，目标是在同一份 notebook 中完成：
# - 从量子化学模型得到 H2 的 4-qubit 哈密顿量
# - 构建一个 H2 专用的 UCC-style 参数化电路
# - 使用 VQE 进行参数优化并与 FCI 基准比较
# - 对照三种 ansatz：`hardwareefficient`、`ucc`、`custom`
#
# ---
#
# ## 理论背景（从分子到量子线路）
#
# 电子哈密顿量（二次量子化）为：
#
# $$
# \hat H = \sum_{pq} h_{pq} a_p^\dagger a_q + \frac{1}{2}\sum_{pqrs} h_{pqrs} a_p^\dagger a_q^\dagger a_r a_s
# $$
#
# 将其映射到 qubit 空间后，得到 Pauli 算符线性组合：
#
# $$
# \hat H_q = c_0 I + \sum_{k} c_k P_k,\quad P_k \in \{I,X,Y,Z\}^{\otimes n}
# $$
#
# VQE 的优化目标是最小化：
#
# $$
# E(\theta) = \langle \psi(\theta) | \hat H_q | \psi(\theta) \rangle
# $$
#
# 将上式代入 Pauli 分解可得：
#
# $$
# E(\theta)=c_0+\sum_k c_k\langle \psi(\theta)|P_k|\psi(\theta)\rangle
# $$
#
# 这说明 VQE 的数值任务可分解为两步：
# 1. 准备参数化态 $|\psi(\theta)\rangle$。
# 2. 估计每个 Pauli 项期望值并按系数加权求和。
#
# 当 ansatz 足够表达基态且优化收敛时，估计能量应接近 FCI 参考值。

# %% [markdown]
# ## 1. 参数配置与运行建议
#
# 本单元配置几何、化学与优化超参数。
#
# ### 关键参数说明
# - `R` 与 `R_UNIT`：H-H 键长及单位。
# - `BASIS`：基组（示例用 `sto-3g`）。
# - `layers`：ansatz 层数。
# - `gradient_method`：推荐在模拟器使用 `autograd` 进行快速验证。
#
# ### 运行建议
# 1. 首次跑通优先保持 `prefer_chips='Simulator'`。
# 2. 若后续切换硬件，可考虑改用 `parameter-shift`。
# 3. 层数与迭代次数增加会提高表达能力，但计算成本也会上升。

# %%
from pathlib import Path
import json

# Geometry / chemistry config
R = 2.6
R_UNIT = 'angstrom'
BASIS = 'sto-3g'
MULTIPLICITY = 1
CHARGE = 0

# VQE config
cfg = {
    'layers': 1,
    'shots': 4096,
    'max_iters': 40,
    'learning_rate': 0.2,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
}

print('R =', R, R_UNIT)
print('Basis =', BASIS)
print('VQE cfg =', cfg)
# Out:
# R = 2.6 angstrom
# Basis = sto-3g
# VQE cfg = {'layers': 1, 'shots': 4096, 'max_iters': 40, 'learning_rate': 0.2, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator'}

# %% [markdown]
# ## 2. 读取 WSL 导出的 4-qubit 哈密顿量系数
#
# For the H₂ molecule in the **STO-3G basis**, there are **4 spin orbitals**, which map to **4 qubits** after fermion-to-qubit transformation (e.g., Jordan–Wigner).
#
# Qubit ordering (one common convention):
#
# | Qubit | Spin Orbital |
# |------|--------------|
# | q0 | 0↑ |
# | q1 | 0↓ |
# | q2 | 1↑ |
# | q3 | 1↓ |
#
# 默认读取文件：
# - `data/chemistry/h2_R2.6_sto-3g.json`
#
# 若文件不存在，请在 WSL 中执行：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_h2.sh 2.6 angstrom
# ```
#
# 读取后可获得：
# - `h2_constant`
# - `h2_4q_terms`
# - `nqubits`
# - `fci_energy`

# %%
from __future__ import annotations

import json
from pathlib import Path

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner

json_path = Path('data/chemistry/h2_R2.6_angstrom_sto-3g.json')
if not json_path.exists():
    raise FileNotFoundError(
        f'Missing {json_path}. Generate it in WSL with:\n'
        'python scripts/export_h2_terms_wsl.py --R 2.6 --unit angstrom '
        '--output data/chemistry/h2_R2.6_angstrom_sto-3g.json'
    )

data = json.loads(json_path.read_text(encoding='utf-8'))

h2_constant = float(data['constant'])
h2_4q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded from:', json_path)
print('nqubits:', nqubits)
print('term_count:', len(h2_4q_terms))
print('fci_energy:', fci_energy)
# Out:
# Loaded from: data\chemistry\h2_R2.6_angstrom_sto-3g.json
# nqubits: 4
# term_count: 14
# fci_energy: -0.9351960308474745

# %% [markdown]
# ## 3. 在 4-qubit 哈密顿量上运行 VQE，并与 FCI 对照
#
# 该单元将：
# - 使用上一步自动生成的 `h2_4q_terms`
# - 在 `num_qubits = 4` 上运行你的框架 VQE（使用默认hardware-efficient ansatz）
# - 计算总能量 `E_total = h2_constant + E_nonconst`
# - 与 `fci_energy` 做误差对比（可验证）

# %%
client = QuantumHardwareClient()
runner = VQERunner(
    client=client,
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
)

result = runner.run_model(
    name='h2_4q_demo_notebook',
    num_qubits=nqubits,
    model='custom',
    hamiltonian=h2_4q_terms,
    prefer_chips=cfg['prefer_chips'],
)

best_total_energy = h2_constant + result.best_energy
abs_error_fci = abs(best_total_energy - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(best_total_energy, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(result.energy_history) + h2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_demo_notebook num_qubits=4 model=custom layers=1 shots=4096 max_iters=40
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=40 layers=1 params=16 ansatz=hardwareefficient shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=0.097025 grad_norm=0.275339
# [vqe] iter 0 new best energy=0.097025
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.056742 grad_norm=0.202049
# [vqe] iter 1 new best energy=-0.056742
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.130675 grad_norm=0.112868
# [vqe] iter 2 new best energy=-0.130675
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.139752 grad_norm=0.130615
# [vqe] iter 3 new best energy=-0.139752
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.138344 grad_norm=0.151034
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.151344 grad_norm=0.141608
# [vqe] iter 5 new best energy=-0.151344
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.172119 grad_norm=0.133684
# [vqe] iter 6 new best energy=-0.172119
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.197318 grad_norm=0.134867
# [vqe] iter 7 new best energy=-0.197318
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.226087 grad_norm=0.135546
# [vqe] iter 8 new best energy=-0.226087
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.255285 grad_norm=0.131750
# [vqe] iter 9 new best energy=-0.255285
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.280633 grad_norm=0.130620
# [vqe] iter 10 new best energy=-0.280633
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.302947 grad_norm=0.136541
# [vqe] iter 11 new best energy=-0.302947
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.325635 grad_norm=0.133582
# [vqe] iter 12 new best energy=-0.325635
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.344575 grad_norm=0.116978
# [vqe] iter 13 new best energy=-0.344575
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.351533 grad_norm=0.114381
# [vqe] iter 14 new best energy=-0.351533
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.348706 grad_norm=0.131891
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.348205 grad_norm=0.137693
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.355080 grad_norm=0.123372
# [vqe] iter 17 new best energy=-0.355080
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.365522 grad_norm=0.096497
# [vqe] iter 18 new best energy=-0.365522
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.373137 grad_norm=0.076255
# [vqe] iter 19 new best energy=-0.373137
# [vqe] iter 20 start
# [vqe] iter 20 energy=-0.374940 grad_norm=0.081488
# [vqe] iter 20 new best energy=-0.374940
# [vqe] iter 21 start
# [vqe] iter 21 energy=-0.374213 grad_norm=0.091319
# [vqe] iter 22 start
# [vqe] iter 22 energy=-0.374845 grad_norm=0.087242
# [vqe] iter 23 start
# [vqe] iter 23 energy=-0.376752 grad_norm=0.072761
# [vqe] iter 23 new best energy=-0.376752
# [vqe] iter 24 start
# [vqe] iter 24 energy=-0.377640 grad_norm=0.064671
# [vqe] iter 24 new best energy=-0.377640
# [vqe] iter 25 start
# [vqe] iter 25 energy=-0.376624 grad_norm=0.073011
# [vqe] iter 26 start
# [vqe] iter 26 energy=-0.375626 grad_norm=0.082534
# [vqe] iter 27 start
# [vqe] iter 27 energy=-0.376898 grad_norm=0.079558
# [vqe] iter 28 start
# [vqe] iter 28 energy=-0.379959 grad_norm=0.063183
# [vqe] iter 28 new best energy=-0.379959
# [vqe] iter 29 start
# [vqe] iter 29 energy=-0.382235 grad_norm=0.044890
# [vqe] iter 29 new best energy=-0.382235
# [vqe] iter 30 start
# [vqe] iter 30 energy=-0.382383 grad_norm=0.043889
# [vqe] iter 30 new best energy=-0.382383
# [vqe] iter 31 start
# [vqe] iter 31 energy=-0.381642 grad_norm=0.053405
# [vqe] iter 32 start
# [vqe] iter 32 energy=-0.381675 grad_norm=0.056408
# [vqe] iter 33 start
# [vqe] iter 33 energy=-0.382656 grad_norm=0.050247
# [vqe] iter 33 new best energy=-0.382656
# [vqe] iter 34 start
# [vqe] iter 34 energy=-0.383785 grad_norm=0.039906
# [vqe] iter 34 new best energy=-0.383785
# [vqe] iter 35 start
# [vqe] iter 35 energy=-0.384515 grad_norm=0.032710
# [vqe] iter 35 new best energy=-0.384515
# [vqe] iter 36 start
# [vqe] iter 36 energy=-0.384655 grad_norm=0.033562
# [vqe] iter 36 new best energy=-0.384655
# [vqe] iter 37 start
# [vqe] iter 37 energy=-0.384328 grad_norm=0.038584
# [vqe] iter 38 start
# [vqe] iter 38 energy=-0.384032 grad_norm=0.041293
# [vqe] iter 39 start
# [vqe] iter 39 energy=-0.384428 grad_norm=0.038086
# === 4-Qubit H2 VQE Result ===
# Estimated total energy:   -0.92892885
# FCI reference energy:     -0.93519603
# Absolute error vs FCI:    0.00626718

# %% [markdown]
# ## 4. 更换ansatz
#
# 改成内置的轻量版ucc（ry 单体旋转 + 邻近耦合激发）

# %%
client = QuantumHardwareClient()
runner = VQERunner(
    client=client,
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
)

result = runner.run_model(
    name='h2_4q_demo_notebook',
    num_qubits=nqubits,
    model='custom',
    hamiltonian=h2_4q_terms,
    prefer_chips=cfg['prefer_chips'],
    ansatz='ucc'
)

best_total_energy = h2_constant + result.best_energy
abs_error_fci = abs(best_total_energy - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(best_total_energy, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(result.energy_history) + h2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_demo_notebook num_qubits=4 model=custom layers=1 shots=4096 max_iters=40
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=40 layers=1 params=7 ansatz=ucc shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.159042 grad_norm=0.112792
# [vqe] iter 0 new best energy=-0.159042
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.181568 grad_norm=0.121955
# [vqe] iter 1 new best energy=-0.181568
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.212451 grad_norm=0.097723
# [vqe] iter 2 new best energy=-0.212451
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.236973 grad_norm=0.098090
# [vqe] iter 3 new best energy=-0.236973
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.262351 grad_norm=0.111756
# [vqe] iter 4 new best energy=-0.262351
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.287045 grad_norm=0.132086
# [vqe] iter 5 new best energy=-0.287045
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.312496 grad_norm=0.153264
# [vqe] iter 6 new best energy=-0.312496
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.341893 grad_norm=0.156057
# [vqe] iter 7 new best energy=-0.341893
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.366389 grad_norm=0.135132
# [vqe] iter 8 new best energy=-0.366389
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.375627 grad_norm=0.104731
# [vqe] iter 9 new best energy=-0.375627
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.369281 grad_norm=0.099615
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.356642 grad_norm=0.127063
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.349382 grad_norm=0.146052
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.351487 grad_norm=0.142076
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.359217 grad_norm=0.123731
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.366999 grad_norm=0.106472
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.372166 grad_norm=0.098349
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.375660 grad_norm=0.091699
# [vqe] iter 17 new best energy=-0.375660
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.378783 grad_norm=0.079862
# [vqe] iter 18 new best energy=-0.378783
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.381173 grad_norm=0.068242
# [vqe] iter 19 new best energy=-0.381173
# [vqe] iter 20 start
# [vqe] iter 20 energy=-0.381992 grad_norm=0.066252
# [vqe] iter 20 new best energy=-0.381992
# [vqe] iter 21 start
# [vqe] iter 21 energy=-0.381320 grad_norm=0.072718
# [vqe] iter 22 start
# [vqe] iter 22 energy=-0.380154 grad_norm=0.078614
# [vqe] iter 23 start
# [vqe] iter 23 energy=-0.379555 grad_norm=0.078903
# [vqe] iter 24 start
# [vqe] iter 24 energy=-0.379978 grad_norm=0.073762
# [vqe] iter 25 start
# [vqe] iter 25 energy=-0.381247 grad_norm=0.065950
# [vqe] iter 26 start
# [vqe] iter 26 energy=-0.382894 grad_norm=0.058569
# [vqe] iter 26 new best energy=-0.382894
# [vqe] iter 27 start
# [vqe] iter 27 energy=-0.384440 grad_norm=0.054004
# [vqe] iter 27 new best energy=-0.384440
# [vqe] iter 28 start
# [vqe] iter 28 energy=-0.385614 grad_norm=0.052969
# [vqe] iter 28 new best energy=-0.385614
# [vqe] iter 29 start
# [vqe] iter 29 energy=-0.386490 grad_norm=0.053247
# [vqe] iter 29 new best energy=-0.386490
# [vqe] iter 30 start
# [vqe] iter 30 energy=-0.387260 grad_norm=0.051106
# [vqe] iter 30 new best energy=-0.387260
# [vqe] iter 31 start
# [vqe] iter 31 energy=-0.387872 grad_norm=0.044912
# [vqe] iter 31 new best energy=-0.387872
# [vqe] iter 32 start
# [vqe] iter 32 energy=-0.388023 grad_norm=0.037800
# [vqe] iter 32 new best energy=-0.388023
# [vqe] iter 33 start
# [vqe] iter 33 energy=-0.387581 grad_norm=0.036612
# [vqe] iter 34 start
# [vqe] iter 34 energy=-0.386924 grad_norm=0.041834
# [vqe] iter 35 start
# [vqe] iter 35 energy=-0.386733 grad_norm=0.046101
# [vqe] iter 36 start
# [vqe] iter 36 energy=-0.387352 grad_norm=0.044803
# [vqe] iter 37 start
# [vqe] iter 37 energy=-0.388443 grad_norm=0.038323
# [vqe] iter 37 new best energy=-0.388443
# [vqe] iter 38 start
# [vqe] iter 38 energy=-0.389329 grad_norm=0.030573
# [vqe] iter 38 new best energy=-0.389329
# [vqe] iter 39 start
# [vqe] iter 39 energy=-0.389624 grad_norm=0.026416
# [vqe] iter 39 new best energy=-0.389624
# === 4-Qubit H2 VQE Result ===
# Estimated total energy:   -0.9338982
# FCI reference energy:     -0.93519603
# Absolute error vs FCI:    0.00129783

# %% [markdown]
# ## 5. 构建 H2 专用 UCC-style Custom Ansatz
#
# 这一步我们手工定义一个“面向 H2 的”参数化电路模板，并交给 `custom` 接口优化。
#
# ### 设计思想
# - 参考态：先准备 Hartree-Fock (HF) 占据态（示例 `|1100>`，与映射约定相关）。
# - 单激发（singles-like）：在占据轨道与虚轨道之间加入参数化混合。
# - 双激发（doubles-like）：加入相关激发近似块，增强电子关联表达能力。
#
# ### The **Unitary Coupled Cluster (UCC)** ansatz is
#
# $$
# U(\theta) = e^{T - T^\dagger}
# $$
# where
#
# $$
# T = T_1 + T_2
# $$
#
# - $T_1$: single excitations
# - $T_2$: double excitations
#
# For the H₂ system, the most important contribution is the **double excitation**
#
# $$
# a_3^\dagger a_2^\dagger a_1 a_0
# $$
#
# Thus the ansatz becomes
#
# $$
# U(\theta) =
# \exp\Big[
# \theta(
# a_3^\dagger a_2^\dagger a_1 a_0
# -
# a_0^\dagger a_1^\dagger a_2 a_3
# )
# \Big]
# $$
#
# ### Pauli Representation
#
# After the **Jordan–Wigner transformation**, the double excitation operator maps to a sum of Pauli strings:
#
# $$
# U(\theta) =
# \exp\left[
# -\frac{i\theta}{8}
# (
# Y_0 X_1 X_2 X_3
# +
# X_0 Y_1 X_2 X_3
# -
# X_0 X_1 Y_2 X_3
# -
# X_0 X_1 X_2 Y_3
# )
# \right]
# $$
#
# Therefore the unitary can be implemented as four Pauli rotations.
#
# ### Circuit Structure
#
# Each Pauli exponential $e^{-i\phi P}$ is implemented with the standard pattern:
#
# 1. **Basis change** (convert X/Y to Z basis)
# 2. **CNOT ladder** to collect parity
# 3. **RZ rotation**
# 4. **Undo CNOT ladder**
# 5. **Undo basis change**

# %%
from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.circuit import QuantumCircuit

def build_h2_ucc_style_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(4)

    # -------------------------
    # Hartree–Fock reference
    # |1100>
    # -------------------------

    qc.x(0)
    qc.x(1)

    # -------------------------------------------------
    # term1: exp[-i θ/8 Y0 X1 X2 X3]
    # -------------------------------------------------

    qc.rx(np.pi/2,0)
    qc.h(1)
    qc.h(2)
    qc.h(3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("theta_1",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.rx(-np.pi/2,0)
    qc.h(1)
    qc.h(2)
    qc.h(3)


    # -------------------------------------------------
    # term2: exp[-i θ/8 X0 Y1 X2 X3]
    # -------------------------------------------------

    qc.h(0)
    qc.rx(np.pi/2,1)
    qc.h(2)
    qc.h(3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("theta_2",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.h(0)
    qc.rx(-np.pi/2,1)
    qc.h(2)
    qc.h(3)


    # -------------------------------------------------
    # term3: exp[+i θ/8 X0 X1 Y2 X3]
    # -------------------------------------------------

    qc.h(0)
    qc.h(1)
    qc.rx(np.pi/2,2)
    qc.h(3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("theta_3",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.h(0)
    qc.h(1)
    qc.rx(-np.pi/2,2)
    qc.h(3)


    # -------------------------------------------------
    # term4: exp[+i θ/8 X0 X1 X2 Y3]
    # -------------------------------------------------

    qc.h(0)
    qc.h(1)
    qc.h(2)
    qc.rx(np.pi/2,3)

    qc.cx(0,1)
    qc.cx(1,2)
    qc.cx(2,3)

    qc.rz("theta_4",3)

    qc.cx(2,3)
    qc.cx(1,2)
    qc.cx(0,1)

    qc.h(0)
    qc.h(1)
    qc.h(2)
    qc.rx(-np.pi/2,3)

    return qc

custom_ansatz_qc = build_h2_ucc_style_symbolic_ansatz()
symbolic_params = sorted(
    [k for k, v in custom_ansatz_qc.params_value.items() if isinstance(k, str) and isinstance(v, str)]
)
print('Detected symbolic parameter count:', len(symbolic_params))
print('First 10 symbolic params:', symbolic_params[:10])
print('Total gates in custom H2-UCC-style ansatz:', len(custom_ansatz_qc.gates))
# Out:
# Detected symbolic parameter count: 4
# First 10 symbolic params: ['theta_1', 'theta_2', 'theta_3', 'theta_4']
# Total gates in custom H2-UCC-style ansatz: 62

# %% [markdown]
# ## 6. 运行 VQE 并对照三种 Ansatz
#
# 在同一哈密顿量上分别运行：
# - `hardwareefficient`：硬件友好、通用性强。
# - `ucc`：内置 UCC-inspired 通用模板。
# - `custom`：本教程构建的 H2 专用 UCC-style 模板。
#
# ### 结果解读方法
# - `best_total = h2_constant + best_nonconst`：估计总能量。
# - `abs_err_fci = |best_total - fci_energy|`：相对 FCI 的误差。
# - 收敛曲线：观察优化稳定性与下降速度。
#
# 通常来说，加入更强问题结构先验的 ansatz，往往在相同预算下能得到更低误差，但并不绝对。

# %%
def run_vqe_with_selected_ansatz(ansatz_name: str, custom_qc=None):
    runner_cmp = VQERunner(
        client=QuantumHardwareClient(),
        layers=cfg['layers'],
        shots=cfg['shots'],
        max_iters=cfg['max_iters'],
        learning_rate=cfg['learning_rate'],
        gradient_method=cfg['gradient_method'],
        seed=cfg['seed'],
    )

    kwargs = {
        'name': f'h2_4q_cmp_{ansatz_name}',
        'num_qubits': nqubits,
        'model': 'custom',
        'hamiltonian': h2_4q_terms,
        'ansatz': ansatz_name,
        'prefer_chips': cfg['prefer_chips'],
    }
    if ansatz_name == 'custom':
        kwargs['custom_ansatz_circuit'] = custom_qc

    res = runner_cmp.run_model(**kwargs)
    e_total = h2_constant + res.best_energy
    return {
        'ansatz': ansatz_name,
        'best_nonconst': float(res.best_energy),
        'best_total': float(e_total),
        'abs_err_fci': float(abs(e_total - fci_energy)),
        'history': res.energy_history,
    }

compare_rows = [
    run_vqe_with_selected_ansatz('hardwareefficient'),
    run_vqe_with_selected_ansatz('ucc'),
    run_vqe_with_selected_ansatz('custom', custom_qc=custom_ansatz_qc),
]

print('=== Ansatz Comparison on H2 4Q ===')
for row in compare_rows:
    print(
        row['ansatz'],
        '| best_total =', round(row['best_total'], 8),
        '| abs_err_fci =', round(row['abs_err_fci'], 8),
    )

plt.figure(figsize=(7, 4))
for row in compare_rows:
    plt.plot(np.array(row['history']) + h2_constant, marker='o', ms=3, label=row['ansatz'])
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Ansatz Comparison (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_cmp_hardwareefficient num_qubits=4 model=custom layers=1 shots=4096 max_iters=40
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=40 layers=1 params=16 ansatz=hardwareefficient shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=0.097025 grad_norm=0.275339
# [vqe] iter 0 new best energy=0.097025
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.056742 grad_norm=0.202049
# [vqe] iter 1 new best energy=-0.056742
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.130675 grad_norm=0.112868
# [vqe] iter 2 new best energy=-0.130675
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.139752 grad_norm=0.130615
# [vqe] iter 3 new best energy=-0.139752
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.138344 grad_norm=0.151034
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.151344 grad_norm=0.141608
# [vqe] iter 5 new best energy=-0.151344
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.172119 grad_norm=0.133684
# [vqe] iter 6 new best energy=-0.172119
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.197318 grad_norm=0.134867
# [vqe] iter 7 new best energy=-0.197318
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.226087 grad_norm=0.135546
# [vqe] iter 8 new best energy=-0.226087
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.255285 grad_norm=0.131750
# [vqe] iter 9 new best energy=-0.255285
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.280633 grad_norm=0.130620
# [vqe] iter 10 new best energy=-0.280633
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.302947 grad_norm=0.136541
# [vqe] iter 11 new best energy=-0.302947
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.325635 grad_norm=0.133582
# [vqe] iter 12 new best energy=-0.325635
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.344575 grad_norm=0.116978
# [vqe] iter 13 new best energy=-0.344575
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.351533 grad_norm=0.114381
# [vqe] iter 14 new best energy=-0.351533
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.348706 grad_norm=0.131891
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.348205 grad_norm=0.137693
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.355080 grad_norm=0.123372
# [vqe] iter 17 new best energy=-0.355080
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.365522 grad_norm=0.096497
# [vqe] iter 18 new best energy=-0.365522
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.373137 grad_norm=0.076255
# [vqe] iter 19 new best energy=-0.373137
# [vqe] iter 20 start
# [vqe] iter 20 energy=-0.374940 grad_norm=0.081488
# [vqe] iter 20 new best energy=-0.374940
# [vqe] iter 21 start
# [vqe] iter 21 energy=-0.374213 grad_norm=0.091319
# [vqe] iter 22 start
# [vqe] iter 22 energy=-0.374845 grad_norm=0.087242
# [vqe] iter 23 start
# [vqe] iter 23 energy=-0.376752 grad_norm=0.072761
# [vqe] iter 23 new best energy=-0.376752
# [vqe] iter 24 start
# [vqe] iter 24 energy=-0.377640 grad_norm=0.064671
# [vqe] iter 24 new best energy=-0.377640
# [vqe] iter 25 start
# [vqe] iter 25 energy=-0.376624 grad_norm=0.073011
# [vqe] iter 26 start
# [vqe] iter 26 energy=-0.375626 grad_norm=0.082534
# [vqe] iter 27 start
# [vqe] iter 27 energy=-0.376898 grad_norm=0.079558
# [vqe] iter 28 start
# [vqe] iter 28 energy=-0.379959 grad_norm=0.063183
# [vqe] iter 28 new best energy=-0.379959
# [vqe] iter 29 start
# [vqe] iter 29 energy=-0.382235 grad_norm=0.044890
# [vqe] iter 29 new best energy=-0.382235
# [vqe] iter 30 start
# [vqe] iter 30 energy=-0.382383 grad_norm=0.043889
# [vqe] iter 30 new best energy=-0.382383
# [vqe] iter 31 start
# [vqe] iter 31 energy=-0.381642 grad_norm=0.053405
# [vqe] iter 32 start
# [vqe] iter 32 energy=-0.381675 grad_norm=0.056408
# [vqe] iter 33 start
# [vqe] iter 33 energy=-0.382656 grad_norm=0.050247
# [vqe] iter 33 new best energy=-0.382656
# [vqe] iter 34 start
# [vqe] iter 34 energy=-0.383785 grad_norm=0.039906
# [vqe] iter 34 new best energy=-0.383785
# [vqe] iter 35 start
# [vqe] iter 35 energy=-0.384515 grad_norm=0.032710
# [vqe] iter 35 new best energy=-0.384515
# [vqe] iter 36 start
# [vqe] iter 36 energy=-0.384655 grad_norm=0.033562
# [vqe] iter 36 new best energy=-0.384655
# [vqe] iter 37 start
# [vqe] iter 37 energy=-0.384328 grad_norm=0.038584
# [vqe] iter 38 start
# [vqe] iter 38 energy=-0.384032 grad_norm=0.041293
# [vqe] iter 39 start
# [vqe] iter 39 energy=-0.384428 grad_norm=0.038086
# [vqe] prepare run: name=h2_4q_cmp_ucc num_qubits=4 model=custom layers=1 shots=4096 max_iters=40
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=40 layers=1 params=7 ansatz=ucc shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.159042 grad_norm=0.112792
# [vqe] iter 0 new best energy=-0.159042
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.181568 grad_norm=0.121955
# [vqe] iter 1 new best energy=-0.181568
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.212451 grad_norm=0.097723
# [vqe] iter 2 new best energy=-0.212451
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.236973 grad_norm=0.098090
# [vqe] iter 3 new best energy=-0.236973
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.262351 grad_norm=0.111756
# [vqe] iter 4 new best energy=-0.262351
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.287045 grad_norm=0.132086
# [vqe] iter 5 new best energy=-0.287045
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.312496 grad_norm=0.153264
# [vqe] iter 6 new best energy=-0.312496
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.341893 grad_norm=0.156057
# [vqe] iter 7 new best energy=-0.341893
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.366389 grad_norm=0.135132
# [vqe] iter 8 new best energy=-0.366389
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.375627 grad_norm=0.104731
# [vqe] iter 9 new best energy=-0.375627
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.369281 grad_norm=0.099615
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.356642 grad_norm=0.127063
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.349382 grad_norm=0.146052
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.351487 grad_norm=0.142076
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.359217 grad_norm=0.123731
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.366999 grad_norm=0.106472
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.372166 grad_norm=0.098349
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.375660 grad_norm=0.091699
# [vqe] iter 17 new best energy=-0.375660
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.378783 grad_norm=0.079862
# [vqe] iter 18 new best energy=-0.378783
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.381173 grad_norm=0.068242
# [vqe] iter 19 new best energy=-0.381173
# [vqe] iter 20 start
# [vqe] iter 20 energy=-0.381992 grad_norm=0.066252
# [vqe] iter 20 new best energy=-0.381992
# [vqe] iter 21 start
# [vqe] iter 21 energy=-0.381320 grad_norm=0.072718
# [vqe] iter 22 start
# [vqe] iter 22 energy=-0.380154 grad_norm=0.078614
# [vqe] iter 23 start
# [vqe] iter 23 energy=-0.379555 grad_norm=0.078903
# [vqe] iter 24 start
# [vqe] iter 24 energy=-0.379978 grad_norm=0.073762
# [vqe] iter 25 start
# [vqe] iter 25 energy=-0.381247 grad_norm=0.065950
# [vqe] iter 26 start
# [vqe] iter 26 energy=-0.382894 grad_norm=0.058569
# [vqe] iter 26 new best energy=-0.382894
# [vqe] iter 27 start
# [vqe] iter 27 energy=-0.384440 grad_norm=0.054004
# [vqe] iter 27 new best energy=-0.384440
# [vqe] iter 28 start
# [vqe] iter 28 energy=-0.385614 grad_norm=0.052969
# [vqe] iter 28 new best energy=-0.385614
# [vqe] iter 29 start
# [vqe] iter 29 energy=-0.386490 grad_norm=0.053247
# [vqe] iter 29 new best energy=-0.386490
# [vqe] iter 30 start
# [vqe] iter 30 energy=-0.387260 grad_norm=0.051106
# [vqe] iter 30 new best energy=-0.387260
# [vqe] iter 31 start
# [vqe] iter 31 energy=-0.387872 grad_norm=0.044912
# [vqe] iter 31 new best energy=-0.387872
# [vqe] iter 32 start
# [vqe] iter 32 energy=-0.388023 grad_norm=0.037800
# [vqe] iter 32 new best energy=-0.388023
# [vqe] iter 33 start
# [vqe] iter 33 energy=-0.387581 grad_norm=0.036612
# [vqe] iter 34 start
# [vqe] iter 34 energy=-0.386924 grad_norm=0.041834
# [vqe] iter 35 start
# [vqe] iter 35 energy=-0.386733 grad_norm=0.046101
# [vqe] iter 36 start
# [vqe] iter 36 energy=-0.387352 grad_norm=0.044803
# [vqe] iter 37 start
# [vqe] iter 37 energy=-0.388443 grad_norm=0.038323
# [vqe] iter 37 new best energy=-0.388443
# [vqe] iter 38 start
# [vqe] iter 38 energy=-0.389329 grad_norm=0.030573
# [vqe] iter 38 new best energy=-0.389329
# [vqe] iter 39 start
# [vqe] iter 39 energy=-0.389624 grad_norm=0.026416
# [vqe] iter 39 new best energy=-0.389624
# [vqe] prepare run: name=h2_4q_cmp_custom num_qubits=4 model=custom layers=1 shots=4096 max_iters=40
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=40 layers=1 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.017433 grad_norm=0.554631
# [vqe] iter 0 new best energy=-0.017433
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.241780 grad_norm=0.506631
# [vqe] iter 1 new best energy=-0.241780
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.380689 grad_norm=0.152632
# [vqe] iter 2 new best energy=-0.380689
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.363017 grad_norm=0.248108
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.291957 grad_norm=0.436100
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.270499 grad_norm=0.470195
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.297235 grad_norm=0.426636
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.344177 grad_norm=0.315587
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.381661 grad_norm=0.145326
# [vqe] iter 8 new best energy=-0.381661
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.389975 grad_norm=0.046812
# [vqe] iter 9 new best energy=-0.389975
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.371861 grad_norm=0.206695
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.348573 grad_norm=0.301619
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.338671 grad_norm=0.331925
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.346442 grad_norm=0.308500
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.365068 grad_norm=0.239260
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.383098 grad_norm=0.133748
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.390874 grad_norm=0.010527
# [vqe] iter 16 new best energy=-0.390874
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.386195 grad_norm=0.104235
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.375313 grad_norm=0.187615
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.367363 grad_norm=0.228867
# [vqe] iter 20 start
# [vqe] iter 20 energy=-0.367595 grad_norm=0.227786
# [vqe] iter 21 start
# [vqe] iter 21 energy=-0.375087 grad_norm=0.188933
# [vqe] iter 22 start
# [vqe] iter 22 energy=-0.384628 grad_norm=0.120115
# [vqe] iter 23 start
# [vqe] iter 23 energy=-0.390419 grad_norm=0.034139
# [vqe] iter 24 start
# [vqe] iter 24 energy=-0.389774 grad_norm=0.051523
# [vqe] iter 25 start
# [vqe] iter 25 energy=-0.384691 grad_norm=0.119525
# [vqe] iter 26 start
# [vqe] iter 26 energy=-0.379888 grad_norm=0.158383
# [vqe] iter 27 start
# [vqe] iter 27 energy=-0.379043 grad_norm=0.164214
# [vqe] iter 28 start
# [vqe] iter 28 energy=-0.382460 grad_norm=0.139011
# [vqe] iter 29 start
# [vqe] iter 29 energy=-0.387467 grad_norm=0.089217
# [vqe] iter 30 start
# [vqe] iter 30 energy=-0.390640 grad_norm=0.025546
# [vqe] iter 31 start
# [vqe] iter 31 energy=-0.390292 grad_norm=0.038175
# [vqe] iter 32 start
# [vqe] iter 32 energy=-0.387529 grad_norm=0.088415
# [vqe] iter 33 start
# [vqe] iter 33 energy=-0.385076 grad_norm=0.115809
# [vqe] iter 34 start
# [vqe] iter 34 energy=-0.384970 grad_norm=0.116839
# [vqe] iter 35 start
# [vqe] iter 35 energy=-0.387134 grad_norm=0.093383
# [vqe] iter 36 start
# [vqe] iter 36 energy=-0.389759 grad_norm=0.051854
# [vqe] iter 37 start
# [vqe] iter 37 energy=-0.390920 grad_norm=0.002292
# [vqe] iter 37 new best energy=-0.390920
# [vqe] iter 38 start
# [vqe] iter 38 energy=-0.390100 grad_norm=0.043608
# [vqe] iter 39 start
# [vqe] iter 39 energy=-0.388446 grad_norm=0.075590
# === Ansatz Comparison on H2 4Q ===
# hardwareefficient | best_total = -0.92892885 | abs_err_fci = 0.00626718
# ucc | best_total = -0.9338982 | abs_err_fci = 0.00129783
# custom | best_total = -0.93519376 | abs_err_fci = 2.27e-06

# %% [markdown]
# ## 7. 在真实硬件上运行线路

# %%
cfg['gradient_method'] = 'parameter-shift'
cfg['prefer_chips'] = 'Hongluo'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['max_iters'] = 15
cfg['learning_rate'] = 0.1

runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
)

kwargs = {
    'name': f'h2_4q_cmp_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': h2_4q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
}

res = runner_cmp.run_model(**kwargs)
e_total = h2_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + h2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_cmp_custom num_qubits=4 model=custom layers=1 shots=4096 max_iters=15
# Yudu configuration loading done!
# The last calibration time was 2026-03-10 19:37:27
# [vqe] candidate chips: ['Yudu']
# Yudu configuration loading done!
# The last calibration time was 2026-03-10 19:37:27
# [vqe] running on chip: Yudu
# [vqe] start optimization: iters=15 layers=1 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=parameter-shift
# [vqe] iter 0 start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 30
#       8 runner_cmp = VQERunner(
#       9     client=QuantumHardwareClient(),
#      10     layers=cfg['layers'],
#    (...)
#      17     readout_mitigation=cfg['readout_mitigation'],
#      18 )
#      20 kwargs = {
#      21     'name': f'h2_4q_cmp_custom',
#      22     'num_qubits': nqubits,
#    (...)
#      27     'prefer_chips': cfg['prefer_chips'],
#      28 }
# ---> 30 res = runner_cmp.run_model(**kwargs)
#      31 e_total = h2_constant + res.best_energy
#      32 abs_error_fci = abs(e_total - fci_energy)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:674, in VQERunner.run_model(self, name, num_qubits, model, model_params, hamiltonian, target_qubits, init_params, callback, prefer_chips, rank_weights, ansatz, custom_ansatz_circuit)
#     672 try:
#     673     print("[vqe] running on chip:", chip_name)
# --> 674     return run_vqe_with_backend(
#     675         self.client,
#     676         name=name,
#     677         num_qubits=num_qubits,
#     678         backend=backend,
#     679         chip_name=chip_name,
#     680         hamiltonian=hamiltonian,
#     681         layers=self.layers,
#     682         shots=self.shots,
#     683         max_iters=self.max_iters,
#     684         learning_rate=self.learning_rate,
#     685         beta1=self.beta1,
#     686         beta2=self.beta2,
#     687         eps=self.eps,
#     688         shift=self.shift,
#     689         zne=self.zne,
#     690         readout_mitigation=self.readout_mitigation,
#     691         target_qubits=target_qubits,
#     692         seed=self.seed,
#     693         init_params=init_params,
#     694         callback=callback,
#     695         gradient_method=self.gradient_method,
#     696         ansatz=run_ansatz,
#     697         custom_ansatz_circuit=custom_ansatz_circuit,
#     698     )
#     699 except Exception as exc:
#     700     last_error = exc
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:530, in run_vqe_with_backend(client, name, num_qubits, backend, chip_name, hamiltonian, layers, shots, max_iters, learning_rate, beta1, beta2, eps, shift, zne, readout_mitigation, target_qubits, seed, init_params, callback, gradient_method, ansatz, custom_ansatz_circuit)
#     528 else:
#     529     qc = _instantiate_transpiled_template(transpiled_template, param_names, params)
# --> 530     energy, expectations = _evaluate_energy_with_backend(
#     531         client,
#     532         qc,
#     533         name=f"{name}_iter{it}",
#     534         num_qubits=num_qubits,
#     535         backend=backend,
#     536         chip_name=chip_name,
#     537         shots=shots,
#     538         hamiltonian=hamiltonian,
#     539         zne=zne,
#     540         readout_mitigation=readout_mitigation,
#     541     )
#     542     grads = _parameter_shift_gradient(
#     543         client,
#     544         params,
#    (...)
#     555         param_names=param_names,
#     556     )
#     558 grad_norm = float(np.linalg.norm(grads))
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:334, in _evaluate_energy_with_backend(client, qc, name, num_qubits, backend, chip_name, shots, hamiltonian, zne, readout_mitigation)
#     320 def _evaluate_energy_with_backend(
#     321     client,
#     322     qc: QuantumCircuit,
#    (...)
#     331     readout_mitigation: bool,
#     332 ) -> Tuple[float, Dict[str, float]]:
#     333     observables = [term[1] for term in hamiltonian]
# --> 334     result = client._run_with_backend(
#     335         qc,
#     336         name,
#     337         num_qubits,
#     338         backend=backend,
#     339         chip_name=chip_name,
#     340         shots=shots,
#     341         zne=zne,
#     342         readout_mitigation=readout_mitigation,
#     343         observables=observables,
#     344         return_probabilities=False,
#     345         print_true=False,
#     346         transpile=False,
#     347     )
#     348     expectations = _ensure_observable_map(observables, result.observable_values)
#     349     energy = _energy_from_expectations(hamiltonian, expectations)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\client.py:326, in QuantumHardwareClient._run_with_backend(self, qc, name, num_qubits, backend, chip_name, shots, zne, readout_mitigation, readout_shots, observables, return_probabilities, target_qubits, merge_groups, qasm_version, print_true, transpile)
#     315 		raise ValueError(
#     316 			f"num_qubits ({num_qubits}) must match len(target_qubits) ({len(target_qubits_group)}) for readout mitigation"
#     317 		)
#     318 	calibration_manager = ReadoutCalibrationManager(
#     319 		cache_dir=Path(__file__).resolve().parent / ".cache",
#     320 		submit_openqasm_async=self._submit_openqasm_async,
#    (...)
#     324 		simulate_counts=simulate_counts,
#     325 	)
# --> 326 	cal = calibration_manager.calibrate_readout(
#     327 		target_qubits=target_qubits_group,
#     328 		shots=readout_shots,
#     329 		chip_name=chip_name,
#     330 		backend=backend,
#     331 		qasm_version=qasm_version,
#     332 		print_true=print_true,
#     333 	)
#     334 	per_qubit = {k: np.asarray(v) for k, v in cal.per_qubit_confusion.items()}
#     336 if print_true:
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\calibration\readout.py:122, in ReadoutCalibrationManager.calibrate_readout(self, target_qubits, shots, chip_name, backend, qasm_version, print_true)
#     120 if not use_simulator:
#     121 	for task_id, q, bits in pending:
# --> 122 		status = self._wait_task(task_id)
#     123 		if status != "Finished":
#     124 			raise RuntimeError(f"readout calibration task {task_id} ended with status {status}")
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\client.py:147, in QuantumHardwareClient._wait_task(self, task_id)
#     145 """Wait for a task to finish and return its final status."""
#     146 while True:
# --> 147 	status = self.tmgr.status(task_id)
#     148 	if status in {"Finished", "Failed", "Canceled"}:
#     149 		return status
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\task.py:88, in Task.status(self, tid)
#      87 def status(self, tid: int = 0):
# ---> 88     time.sleep(0.2)
#      89     return self.request(f'{self.URL}/task/status/{tid}')
#
# KeyboardInterrupt:
