# %% [markdown]
# <!-- # LiH 分子 VQE 完整教程（6-Qubit）
#
# 接下来我们考虑LiH分子：
# - 通过 freeze 和 remove，将 LiH 的active space encode 成 6-qubit 哈密顿量
# - 构建一个 UCC-style 参数化电路
# - 使用 VQE 进行参数优化并与 FCI 基准比较 -->

# %% [markdown]
# ## 1. 参数配置与运行建议
# 本项目中，我们开始用6比特做LiH分子

# %%
from pathlib import Path
import json
import math

# Geometry / chemistry config
R = 2.2
R_UNIT = 'angstrom'
BASIS = 'sto-3g'
MULTIPLICITY = 1
CHARGE = 0

# VQE config
cfg = {
    'layers': 3,
    'shots': 4096,
    'max_iters': 20,
    'learning_rate': 0.03,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2,
}

print('R =', R, R_UNIT)
print('Basis =', BASIS)
print('VQE cfg =', cfg)
# Out:
# R = 2.2 angstrom
# Basis = sto-3g
# VQE cfg = {'layers': 3, 'shots': 4096, 'max_iters': 20, 'learning_rate': 0.03, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %% [markdown]
# ## 2. 读取 WSL 导出的 6-qubit 哈密顿量系数
#
# For the LiH molecule in the **STO-3G basis**, with frozen 1a1 and removed 1e1, 2e1, there are **6 spin orbitals**, which map to **6 qubits** after fermion-to-qubit transformation (e.g., Jordan–Wigner).
#
# 默认读取文件：
# - `data/chemistry/lih_R2.2_sto-3g_6q.json`
#
# 若文件不存在，请在 WSL 中执行：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_lih.sh 2.2 angstrom
# ```

# %%
from __future__ import annotations

import os
import json
from pathlib import Path

# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner

json_path = Path('data/chemistry/lih_R2.2_angstrom_sto-3g_6q.json')
data = json.loads(json_path.read_text(encoding='utf-8'))

lih_constant = float(data['constant'])
lih_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded from:', json_path)
print('nqubits:', nqubits)
print('term_count:', len(lih_6q_terms))
print('fci_energy:', fci_energy)
# Out:
# Loaded from: data\chemistry\lih_R2.2_angstrom_sto-3g_6q.json
# nqubits: 6
# term_count: 117
# fci_energy: -7.845683623197186

# %% [markdown]
# ## 3. 构建 LiH 专用 UCC-style Custom Ansatz
#
# 参照Nat. Phys. 20, 1240 (2024)，结合对称性限制和激发能量，只考虑UCC中的最关键项，包括
#
# $$
# a_5^\dagger a_2^\dagger a_1 a_0, \quad a_4^\dagger a_3^\dagger a_1 a_0, \quad a_5^\dagger a_4^\dagger a_1 a_0
# $$
#
# 对应的UCC为
#
# $$
# U(\theta) =
# \exp\left[
# -i\theta_3 Y_0X_1Z_2Z_3X_4Y_5 -i\theta_2 Y_0X_1Z_2X_3Y_4 -i\theta_1 Y_0 X_1 X_2 Z_3 Z_4 Y_5
# \right]
# $$

# %%
from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.circuit import QuantumCircuit

def build_h2_ucc_style_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(6)

    # -------------------------
    # Hartree–Fock reference or "singlet" reference state preparation
    # |110000> or (|110000> - |001100>)/sqrt(2)
    # -------------------------

    qc.ry("theta_0", 0)
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)

    qc.x(0)
    qc.x(1)

    qc.pauli_evolution("theta_1", "X0 X1 Y2 Z3 Z4 X5")
    qc.pauli_evolution("theta_2", "X0 X1 Z2 Y3 X4")
    qc.pauli_evolution("theta_3", "X0 X1 Z2 Z3 Y4 X5")
    return qc

custom_ansatz_qc = build_h2_ucc_style_symbolic_ansatz()
symbolic_params = sorted(
    [k for k, v in custom_ansatz_qc.params_value.items() if isinstance(k, str) and isinstance(v, str)]
)
print('Total gates in custom H2-UCC-style ansatz:', len(custom_ansatz_qc.gates))
# Out:
# Total gates in custom H2-UCC-style ansatz: 67

# %% [markdown]
# ## 4. 运行 VQE 并验证 Ansatz
#
# 通常来说，加入更强问题结构先验的 ansatz，往往在相同预算下能得到更低误差，但并不绝对。

# %%
runner = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
)

kwargs = {
    'name': f'lih_6q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0]*len(symbolic_params),
}

res = runner.run_model(**kwargs)
e_total = lih_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 6-Qubit LiH VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=lih_6q_custom num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.649336 grad_norm=0.148236
# [vqe] iter 0 new best energy=-0.649336
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.656303 grad_norm=0.134752
# [vqe] iter 1 new best energy=-0.656303
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.662383 grad_norm=0.120923
# [vqe] iter 2 new best energy=-0.662383
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.667532 grad_norm=0.106849
# [vqe] iter 3 new best energy=-0.667532
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.671723 grad_norm=0.092756
# [vqe] iter 4 new best energy=-0.671723
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.674978 grad_norm=0.079037
# [vqe] iter 5 new best energy=-0.674978
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.677371 grad_norm=0.066283
# [vqe] iter 6 new best energy=-0.677371
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.679019 grad_norm=0.055295
# [vqe] iter 7 new best energy=-0.679019
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.680066 grad_norm=0.046931
# [vqe] iter 8 new best energy=-0.680066
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.680685 grad_norm=0.041612
# [vqe] iter 9 new best energy=-0.680685
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.681058 grad_norm=0.038811
# [vqe] iter 10 new best energy=-0.681058
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.681333 grad_norm=0.037304
# [vqe] iter 11 new best energy=-0.681333
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.681596 grad_norm=0.035988
# [vqe] iter 12 new best energy=-0.681596
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.681872 grad_norm=0.034314
# [vqe] iter 13 new best energy=-0.681872
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.682146 grad_norm=0.032229
# [vqe] iter 14 new best energy=-0.682146
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.682390 grad_norm=0.029975
# [vqe] iter 15 new best energy=-0.682390
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.682576 grad_norm=0.027931
# [vqe] iter 16 new best energy=-0.682576
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.682689 grad_norm=0.026496
# [vqe] iter 17 new best energy=-0.682689
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.682721 grad_norm=0.025978
# [vqe] iter 18 new best energy=-0.682721
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.682674 grad_norm=0.026472
# === 6-Qubit LiH VQE Result ===
# Estimated total energy:   -7.841379
# FCI reference energy:     -7.84568362
# Absolute error vs FCI:    0.00430463

# %% [markdown]
# ## 5. 在真实硬件上运行线路
# 结合ZNE、REM和CF

# %%
cfg['prefer_chips'] = 'Dongling'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
cfg['gradient_method'] = 'parameter-shift'

runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    clifford_fitting=cfg['clifford_fitting'],
    clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
)

kwargs = {
    'name': f'lih_6q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
}

res = runner_cmp.run_model(**kwargs)
e_total = lih_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=lih_6q_custom num_qubits=6 model=custom layers=3 shots=4096 max_iters=20

# %% [markdown]
# ## 6. 计算完整的能量曲线

# %%
R_range = np.arange(0.5, 3.01, 0.3)
energy_ucc = []
for r, R in enumerate(R_range):
    json_path = Path(f'data/chemistry/lih_R{R:.1f}_angstrom_sto-3g_6q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))

    lih_constant = float(data['constant'])
    lih_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
    nqubits = int(data['nqubits'])
    fci_energy = float(data['fci_energy'])

    runner = VQERunner(
        client=QuantumHardwareClient(),
        layers=cfg['layers'],
        shots=cfg['shots'],
        max_iters=cfg['max_iters'],
        learning_rate=cfg['learning_rate'],
        gradient_method=cfg['gradient_method'],
        seed=cfg['seed'],
        shift=cfg['shift'],
    )

    kwargs = {
        'name': f'lih_6q_custom_R{R:.1f}',
        'num_qubits': nqubits,
        'model': 'custom',
        'hamiltonian': lih_6q_terms,
        'ansatz': 'custom',
        'custom_ansatz_circuit': custom_ansatz_qc,
        'prefer_chips': cfg['prefer_chips'],
        'init_params': [0]*len(symbolic_params),
    }

    res = runner.run_model(**kwargs)
    e_total = lih_constant + res.best_energy
    abs_error_fci = abs(e_total - fci_energy)
    energy_ucc.append({
        'R': R,
        'e_total': e_total,
    })
# Out:
# [vqe] prepare run: name=lih_6q_custom_R0.5 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.945388 grad_norm=0.114512
# [vqe] iter 0 new best energy=-0.945388
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.949907 grad_norm=0.090316
# [vqe] iter 1 new best energy=-0.949907
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.953061 grad_norm=0.066798
# [vqe] iter 2 new best energy=-0.953061
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.954899 grad_norm=0.045256
# [vqe] iter 3 new best energy=-0.954899
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.955655 grad_norm=0.028220
# [vqe] iter 4 new best energy=-0.955655
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.955740 grad_norm=0.020494
# [vqe] iter 5 new best energy=-0.955740
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.955528 grad_norm=0.024239
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.955259 grad_norm=0.031719
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.955052 grad_norm=0.038011
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.954953 grad_norm=0.041931
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.954957 grad_norm=0.043446
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.955040 grad_norm=0.042848
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.955178 grad_norm=0.040446
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.955355 grad_norm=0.036497
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.955555 grad_norm=0.031280
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.955754 grad_norm=0.025188
# [vqe] iter 15 new best energy=-0.955754
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.955926 grad_norm=0.018791
# [vqe] iter 16 new best energy=-0.955926
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.956054 grad_norm=0.013010
# [vqe] iter 17 new best energy=-0.956054
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.956129 grad_norm=0.009672
# [vqe] iter 18 new best energy=-0.956129
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.956154 grad_norm=0.010598
# [vqe] iter 19 new best energy=-0.956154
# [vqe] prepare run: name=lih_6q_custom_R0.8 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.882739 grad_norm=0.128862
# [vqe] iter 0 new best energy=-0.882739
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.887636 grad_norm=0.108010
# [vqe] iter 1 new best energy=-0.887636
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.891184 grad_norm=0.088200
# [vqe] iter 2 new best energy=-0.891184
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.893545 grad_norm=0.070346
# [vqe] iter 3 new best energy=-0.893545
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.895034 grad_norm=0.055174
# [vqe] iter 4 new best energy=-0.895034
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.896023 grad_norm=0.042242
# [vqe] iter 5 new best energy=-0.896023
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.896739 grad_norm=0.030686
# [vqe] iter 6 new best energy=-0.896739
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.897213 grad_norm=0.021146
# [vqe] iter 7 new best energy=-0.897213
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.897416 grad_norm=0.017081
# [vqe] iter 8 new best energy=-0.897416
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.897345 grad_norm=0.021135
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.897051 grad_norm=0.028926
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.896631 grad_norm=0.036606
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.896218 grad_norm=0.042537
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.895937 grad_norm=0.045992
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.895858 grad_norm=0.046801
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.895981 grad_norm=0.045200
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.896254 grad_norm=0.041652
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.896600 grad_norm=0.036698
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.896947 grad_norm=0.030894
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.897237 grad_norm=0.024799
# [vqe] prepare run: name=lih_6q_custom_R1.1 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.935515 grad_norm=0.129554
# [vqe] iter 0 new best energy=-0.935515
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.940551 grad_norm=0.107179
# [vqe] iter 1 new best energy=-0.940551
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.944135 grad_norm=0.086057
# [vqe] iter 2 new best energy=-0.944135
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.946471 grad_norm=0.067190
# [vqe] iter 3 new best energy=-0.946471
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.947854 grad_norm=0.051742
# [vqe] iter 4 new best energy=-0.947854
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.948664 grad_norm=0.039610
# [vqe] iter 5 new best energy=-0.948664
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.949189 grad_norm=0.029863
# [vqe] iter 6 new best energy=-0.949189
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.949508 grad_norm=0.023200
# [vqe] iter 7 new best energy=-0.949508
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.949608 grad_norm=0.022206
# [vqe] iter 8 new best energy=-0.949608
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.949486 grad_norm=0.026992
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.949187 grad_norm=0.034080
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.948806 grad_norm=0.040720
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.948462 grad_norm=0.045507
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.948259 grad_norm=0.047827
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.948250 grad_norm=0.047576
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.948432 grad_norm=0.044975
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.948755 grad_norm=0.040409
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.949142 grad_norm=0.034356
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.949509 grad_norm=0.027391
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.949790 grad_norm=0.020186
# [vqe] iter 19 new best energy=-0.949790
# [vqe] prepare run: name=lih_6q_custom_R1.4 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.908322 grad_norm=0.131120
# [vqe] iter 0 new best energy=-0.908322
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.913603 grad_norm=0.109767
# [vqe] iter 1 new best energy=-0.913603
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.917487 grad_norm=0.089333
# [vqe] iter 2 new best energy=-0.917487
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.920120 grad_norm=0.070623
# [vqe] iter 3 new best energy=-0.920120
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.921744 grad_norm=0.054819
# [vqe] iter 4 new best energy=-0.921744
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.922656 grad_norm=0.042755
# [vqe] iter 5 new best energy=-0.922656
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.923188 grad_norm=0.033895
# [vqe] iter 6 new best energy=-0.923188
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.923526 grad_norm=0.027629
# [vqe] iter 7 new best energy=-0.923526
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.923712 grad_norm=0.024572
# [vqe] iter 8 new best energy=-0.923712
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.923737 grad_norm=0.025596
# [vqe] iter 9 new best energy=-0.923737
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.923602 grad_norm=0.029860
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.923341 grad_norm=0.035385
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.923025 grad_norm=0.040532
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.922743 grad_norm=0.044268
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.922576 grad_norm=0.046040
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.922571 grad_norm=0.045674
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.922732 grad_norm=0.043278
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.923026 grad_norm=0.039118
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.923393 grad_norm=0.033540
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.923761 grad_norm=0.026966
# [vqe] iter 19 new best energy=-0.923761
# [vqe] prepare run: name=lih_6q_custom_R1.7 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.816127 grad_norm=0.135752
# [vqe] iter 0 new best energy=-0.816127
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.821874 grad_norm=0.117336
# [vqe] iter 1 new best energy=-0.821874
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.826401 grad_norm=0.099287
# [vqe] iter 2 new best energy=-0.826401
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.829750 grad_norm=0.082089
# [vqe] iter 3 new best energy=-0.829750
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.832075 grad_norm=0.066435
# [vqe] iter 4 new best energy=-0.832075
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.833562 grad_norm=0.053317
# [vqe] iter 5 new best energy=-0.833562
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.834441 grad_norm=0.043408
# [vqe] iter 6 new best energy=-0.834441
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.834973 grad_norm=0.036323
# [vqe] iter 7 new best energy=-0.834973
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.835337 grad_norm=0.031160
# [vqe] iter 8 new best energy=-0.835337
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.835598 grad_norm=0.027516
# [vqe] iter 9 new best energy=-0.835598
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.835758 grad_norm=0.025683
# [vqe] iter 10 new best energy=-0.835758
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.835801 grad_norm=0.026088
# [vqe] iter 11 new best energy=-0.835801
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.835723 grad_norm=0.028557
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.835538 grad_norm=0.032257
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.835285 grad_norm=0.036185
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.835026 grad_norm=0.039506
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.834828 grad_norm=0.041636
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.834742 grad_norm=0.042257
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.834793 grad_norm=0.041293
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.834974 grad_norm=0.038849
# [vqe] prepare run: name=lih_6q_custom_R2.0 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.712500 grad_norm=0.142799
# [vqe] iter 0 new best energy=-0.712500
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.718920 grad_norm=0.127491
# [vqe] iter 1 new best energy=-0.718920
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.724326 grad_norm=0.112079
# [vqe] iter 2 new best energy=-0.724326
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.728691 grad_norm=0.096787
# [vqe] iter 3 new best energy=-0.728691
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.732046 grad_norm=0.081998
# [vqe] iter 4 new best energy=-0.732046
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.734491 grad_norm=0.068284
# [vqe] iter 5 new best energy=-0.734491
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.736161 grad_norm=0.056445
# [vqe] iter 6 new best energy=-0.736161
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.737217 grad_norm=0.047286
# [vqe] iter 7 new best energy=-0.737217
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.737856 grad_norm=0.041018
# [vqe] iter 8 new best energy=-0.737856
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.738271 grad_norm=0.036944
# [vqe] iter 9 new best energy=-0.738271
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.738592 grad_norm=0.033995
# [vqe] iter 10 new best energy=-0.738592
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.738871 grad_norm=0.031465
# [vqe] iter 11 new best energy=-0.738871
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.739110 grad_norm=0.029202
# [vqe] iter 12 new best energy=-0.739110
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.739289 grad_norm=0.027449
# [vqe] iter 13 new best energy=-0.739289
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.739390 grad_norm=0.026598
# [vqe] iter 14 new best energy=-0.739390
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.739400 grad_norm=0.026938
# [vqe] iter 15 new best energy=-0.739400
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.739320 grad_norm=0.028437
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.739163 grad_norm=0.030722
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.738963 grad_norm=0.033241
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.738765 grad_norm=0.035436
# [vqe] prepare run: name=lih_6q_custom_R2.3 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.620341 grad_norm=0.151073
# [vqe] iter 0 new best energy=-0.620341
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.627608 grad_norm=0.138411
# [vqe] iter 1 new best energy=-0.627608
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.634047 grad_norm=0.125305
# [vqe] iter 2 new best energy=-0.634047
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.639608 grad_norm=0.111805
# [vqe] iter 3 new best energy=-0.639608
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.644251 grad_norm=0.098067
# [vqe] iter 4 new best energy=-0.644251
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.647963 grad_norm=0.084399
# [vqe] iter 5 new best energy=-0.647963
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.650778 grad_norm=0.071302
# [vqe] iter 6 new best energy=-0.650778
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.652783 grad_norm=0.059505
# [vqe] iter 7 new best energy=-0.652783
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.654102 grad_norm=0.049922
# [vqe] iter 8 new best energy=-0.654102
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.654893 grad_norm=0.043381
# [vqe] iter 9 new best energy=-0.654893
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.655330 grad_norm=0.039996
# [vqe] iter 10 new best energy=-0.655330
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.655589 grad_norm=0.038811
# [vqe] iter 11 new best energy=-0.655589
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.655803 grad_norm=0.038409
# [vqe] iter 12 new best energy=-0.655803
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.656044 grad_norm=0.037735
# [vqe] iter 13 new best energy=-0.656044
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.656328 grad_norm=0.036346
# [vqe] iter 14 new best energy=-0.656328
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.656632 grad_norm=0.034248
# [vqe] iter 15 new best energy=-0.656632
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.656920 grad_norm=0.031710
# [vqe] iter 16 new best energy=-0.656920
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.657160 grad_norm=0.029121
# [vqe] iter 17 new best energy=-0.657160
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.657330 grad_norm=0.026896
# [vqe] iter 18 new best energy=-0.657330
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.657419 grad_norm=0.025404
# [vqe] iter 19 new best energy=-0.657419
# [vqe] prepare run: name=lih_6q_custom_R2.6 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.543897 grad_norm=0.159766
# [vqe] iter 0 new best energy=-0.543897
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.552153 grad_norm=0.149256
# [vqe] iter 1 new best energy=-0.552153
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.559738 grad_norm=0.138062
# [vqe] iter 2 new best energy=-0.559738
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.566594 grad_norm=0.126130
# [vqe] iter 3 new best energy=-0.566594
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.572655 grad_norm=0.113464
# [vqe] iter 4 new best energy=-0.572655
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.577863 grad_norm=0.100149
# [vqe] iter 5 new best energy=-0.577863
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.582168 grad_norm=0.086400
# [vqe] iter 6 new best energy=-0.582168
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.585545 grad_norm=0.072617
# [vqe] iter 7 new best energy=-0.585545
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.588009 grad_norm=0.059493
# [vqe] iter 8 new best energy=-0.588009
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.589628 grad_norm=0.048126
# [vqe] iter 9 new best energy=-0.589628
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.590529 grad_norm=0.040059
# [vqe] iter 10 new best energy=-0.590529
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.590884 grad_norm=0.036650
# [vqe] iter 11 new best energy=-0.590884
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.590894 grad_norm=0.037592
# [vqe] iter 12 new best energy=-0.590894
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.590755 grad_norm=0.040783
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.590632 grad_norm=0.044095
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.590635 grad_norm=0.046282
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.590808 grad_norm=0.046838
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.591144 grad_norm=0.045703
# [vqe] iter 17 new best energy=-0.591144
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.591597 grad_norm=0.043071
# [vqe] iter 18 new best energy=-0.591597
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.592103 grad_norm=0.039274
# [vqe] iter 19 new best energy=-0.592103
# [vqe] prepare run: name=lih_6q_custom_R2.9 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.482132 grad_norm=0.168355
# [vqe] iter 0 new best energy=-0.482132
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.491445 grad_norm=0.159633
# [vqe] iter 1 new best energy=-0.491445
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.500211 grad_norm=0.150051
# [vqe] iter 2 new best energy=-0.500211
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.508366 grad_norm=0.139506
# [vqe] iter 3 new best energy=-0.508366
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.515836 grad_norm=0.127922
# [vqe] iter 4 new best energy=-0.515836
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.522545 grad_norm=0.115263
# [vqe] iter 5 new best energy=-0.522545
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.528416 grad_norm=0.101551
# [vqe] iter 6 new best energy=-0.528416
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.533378 grad_norm=0.086891
# [vqe] iter 7 new best energy=-0.533378
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.537375 grad_norm=0.071511
# [vqe] iter 8 new best energy=-0.537375
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.540377 grad_norm=0.055849
# [vqe] iter 9 new best energy=-0.540377
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.542393 grad_norm=0.040771
# [vqe] iter 10 new best energy=-0.542393
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.543485 grad_norm=0.028271
# [vqe] iter 11 new best energy=-0.543485
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.543776 grad_norm=0.022907
# [vqe] iter 12 new best energy=-0.543776
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.543452 grad_norm=0.027566
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.542745 grad_norm=0.036841
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.541898 grad_norm=0.046123
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.541126 grad_norm=0.053653
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.540591 grad_norm=0.058791
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.540376 grad_norm=0.061377
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.540500 grad_norm=0.061502

# %%
from matplotlib import pyplot as plt

R_values = [res['R'] for res in energy_ucc]
estimated_energies_ucc = [res['e_total'] for res in energy_ucc]
R_range = np.arange(0.5, 3.01, 0.1)
fci_energies = []
for R in R_range:
    json_path = Path(f'data/chemistry/lih_R{R:.1f}_angstrom_sto-3g_6q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))
    fci_energies.append(float(data['fci_energy']))
plt.figure(figsize=(10, 6))
plt.scatter(R_values, estimated_energies_ucc, marker='s', label='Unitary Coupled Cluster Ansatz')
plt.plot(R_range, fci_energies, 'k-', label='FCI Energy')
plt.xlabel('Interatomic Distance R (angstrom)')
plt.ylabel('Energy (Hartree)')
plt.legend()
plt.title('LiH Molecule Energy vs Interatomic Distance')
plt.tick_params(right=True, top=True)
plt.tight_layout()
plt.show()
