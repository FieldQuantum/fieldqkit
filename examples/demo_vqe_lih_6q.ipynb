# %% [markdown]
# <!-- # LiH 分子 VQE 完整教程（6-Qubit）
#
# 接下来我们考虑LiH分子：
# - 通过 freeze 和 remove，将 LiH 的active space encode 成 6-qubit 哈密顿量
# - 构建一个 UCC-style 参数化电路
# - 使用 VQE 进行参数优化并与 FCI 基准比较 -->

# %% [markdown]
# ## 1. 参数配置与运行建议
# 本项目中，我们开始用6比特做LiH分子

# %%
from pathlib import Path
import json
import math

# Geometry / chemistry config
R = 2.2
R_UNIT = 'angstrom'
BASIS = 'sto-3g'
MULTIPLICITY = 1
CHARGE = 0

# VQE config
cfg = {
    'layers': 3,
    'shots': 4096,
    'max_iters': 10,
    'learning_rate': 0.05,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2,
}

print('R =', R, R_UNIT)
print('Basis =', BASIS)
print('VQE cfg =', cfg)
# Out:
# R = 2.2 angstrom
# Basis = sto-3g
# VQE cfg = {'layers': 3, 'shots': 4096, 'max_iters': 10, 'learning_rate': 0.05, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %% [markdown]
# ## 2. 读取 WSL 导出的 6-qubit 哈密顿量系数
#
# For the LiH molecule in the **STO-3G basis**, with frozen 1a1 and removed 1e1, 2e1, there are **6 spin orbitals**, which map to **6 qubits** after fermion-to-qubit transformation (e.g., Jordan–Wigner).
#
# 默认读取文件：
# - `data/chemistry/lih_R2.2_sto-3g_6q.json`
#
# 若文件不存在，请在 WSL 中执行：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_lih.sh 2.2 angstrom
# ```

# %%
from __future__ import annotations

import os
import json
from pathlib import Path

# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner

json_path = Path('data/chemistry/lih_R2.2_angstrom_sto-3g_6q.json')
data = json.loads(json_path.read_text(encoding='utf-8'))

lih_constant = float(data['constant'])
lih_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded from:', json_path)
print('nqubits:', nqubits)
print('term_count:', len(lih_6q_terms))
print('fci_energy:', fci_energy)
# Out:
# Loaded from: data\chemistry\lih_R2.2_angstrom_sto-3g_6q.json
# nqubits: 6
# term_count: 117
# fci_energy: -7.845683623197186

# %% [markdown]
# ## 3. 构建 LiH 专用 UCC-style Custom Ansatz
#
# 参照Nat. Phys. 20, 1240 (2024)，结合对称性限制和激发能量，只考虑UCC中的最关键项，包括
#
# $$
# a_5^\dagger a_2^\dagger a_1 a_0, \quad a_4^\dagger a_3^\dagger a_1 a_0, \quad a_5^\dagger a_4^\dagger a_1 a_0
# $$
#
# 对应的UCC为
#
# $$
# U(\theta) =
# \exp\left[
# -i\theta_3 Y_0X_1Z_2Z_3X_4Y_5 -i\theta_2 Y_0X_1Z_2X_3Y_4 -i\theta_1 Y_0 X_1 X_2 Z_3 Z_4 Y_5
# \right]
# $$

# %%
from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.circuit import QuantumCircuit

def build_h2_ucc_style_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(6)

    # -------------------------
    # Hartree–Fock reference or "singlet" reference state preparation
    # |110000> or (|110000> - |001100>)/sqrt(2)
    # -------------------------

    qc.ry("theta_0", 0)
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)

    qc.x(0)
    qc.x(1)

    qc.pauli_evolution("theta_1", "X0 X1 Y2 Z3 Z4 X5")
    qc.pauli_evolution("theta_2", "X0 X1 Z2 Y3 X4")
    qc.pauli_evolution("theta_3", "X0 X1 Z2 Z3 Y4 X5")
    return qc

custom_ansatz_qc = build_h2_ucc_style_symbolic_ansatz()
symbolic_params = sorted(
    [k for k, v in custom_ansatz_qc.params_value.items() if isinstance(k, str) and isinstance(v, str)]
)
print('Total gates in custom H2-UCC-style ansatz:', len(custom_ansatz_qc.gates))
# Out:
# Total gates in custom H2-UCC-style ansatz: 67

# %% [markdown]
# ## 4. 运行 VQE 并验证 Ansatz
#
# 通常来说，加入更强问题结构先验的 ansatz，往往在相同预算下能得到更低误差，但并不绝对。

# %%
runner = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
    measurement_mode='auto',
)

kwargs = {
    'name': f'lih_6q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01]*len(symbolic_params),
}

res = runner.run_model(**kwargs)
e_total = lih_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 6-Qubit LiH VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'LiH 6-Qubit VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=lih_6q_custom num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.647740 grad_norm=0.138405
# [vqe] iter 0 new best energy=-0.647740
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.659145 grad_norm=0.128955
# [vqe] iter 1 new best energy=-0.659145
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.667931 grad_norm=0.105844
# [vqe] iter 2 new best energy=-0.667931
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.674163 grad_norm=0.082754
# [vqe] iter 3 new best energy=-0.674163
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.678003 grad_norm=0.061785
# [vqe] iter 4 new best energy=-0.678003
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.679945 grad_norm=0.046504
# [vqe] iter 5 new best energy=-0.679945
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.680654 grad_norm=0.040247
# [vqe] iter 6 new best energy=-0.680654
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.680781 grad_norm=0.041064
# [vqe] iter 7 new best energy=-0.680781
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.680770 grad_norm=0.043593
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.680789 grad_norm=0.045050
# [vqe] iter 9 new best energy=-0.680789
# === 6-Qubit LiH VQE Result ===
# Estimated total energy:   -7.83944649
# FCI reference energy:     -7.84568362
# Absolute error vs FCI:    0.00623713

# %% [markdown]
# ## 5. 在真实硬件上运行线路
# 结合ZNE、REM和CF

# %%
cfg['prefer_chips'] = 'Baihua'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
cfg['gradient_method'] = 'parameter-shift'
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    # clifford_fitting=cfg['clifford_fitting'],
    # clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
)

kwargs = {
    'name': f'lih_6q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0]*len(symbolic_params),
}

res = runner_cmp.run_model(**kwargs)
e_total = lih_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 6-Qubit LiH VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'LiH VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. 计算完整的能量曲线

# %%
R_range = np.arange(0.5, 3.01, 0.3)
energy_ucc = []
cfg['gradient_method'] = 'autograd'
for r, R in enumerate(R_range):
    json_path = Path(f'data/chemistry/lih_R{R:.1f}_angstrom_sto-3g_6q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))

    lih_constant = float(data['constant'])
    lih_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
    nqubits = int(data['nqubits'])
    fci_energy = float(data['fci_energy'])

    runner = VQERunner(
        client=QuantumHardwareClient(),
        layers=cfg['layers'],
        shots=cfg['shots'],
        max_iters=cfg['max_iters'],
        learning_rate=cfg['learning_rate'],
        gradient_method=cfg['gradient_method'],
        seed=cfg['seed'],
        shift=cfg['shift'],
    )

    kwargs = {
        'name': f'lih_6q_custom_R{R:.1f}',
        'num_qubits': nqubits,
        'model': 'custom',
        'hamiltonian': lih_6q_terms,
        'ansatz': 'custom',
        'custom_ansatz_circuit': custom_ansatz_qc,
        'prefer_chips': cfg['prefer_chips'],
        'init_params': [0]*len(symbolic_params),
    }

    res = runner.run_model(**kwargs)
    e_total = lih_constant + res.best_energy
    abs_error_fci = abs(e_total - fci_energy)
    energy_ucc.append({
        'R': R,
        'e_total': e_total,
    })
# Out:
# [vqe] prepare run: name=lih_6q_custom_R0.5 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.945388 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.945388
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.945388 grad_norm=0.026797
# [vqe] iter 1 new best energy=-0.945388
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.946538 grad_norm=0.099164
# [vqe] iter 2 new best energy=-0.946538
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.950387 grad_norm=0.073649
# [vqe] iter 3 new best energy=-0.950387
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.953754 grad_norm=0.042462
# [vqe] iter 4 new best energy=-0.953754
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.955400 grad_norm=0.012727
# [vqe] iter 5 new best energy=-0.955400
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.955188 grad_norm=0.023642
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.953923 grad_norm=0.044953
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.952795 grad_norm=0.056767
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.952501 grad_norm=0.058867
# [vqe] prepare run: name=lih_6q_custom_R0.8 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.882739 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.882739
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.882739 grad_norm=0.045304
# [vqe] iter 1 new best energy=-0.882739
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.884360 grad_norm=0.115944
# [vqe] iter 2 new best energy=-0.884360
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.888714 grad_norm=0.093771
# [vqe] iter 3 new best energy=-0.888714
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.893123 grad_norm=0.065778
# [vqe] iter 4 new best energy=-0.893123
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.896198 grad_norm=0.035429
# [vqe] iter 5 new best energy=-0.896198
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.897430 grad_norm=0.006392
# [vqe] iter 6 new best energy=-0.897430
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.896977 grad_norm=0.022746
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.895590 grad_norm=0.043963
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.894252 grad_norm=0.057515
# [vqe] prepare run: name=lih_6q_custom_R1.1 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.935515 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.935515
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.935515 grad_norm=0.040278
# [vqe] iter 1 new best energy=-0.935515
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.936767 grad_norm=0.117705
# [vqe] iter 2 new best energy=-0.936767
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.941414 grad_norm=0.093702
# [vqe] iter 3 new best energy=-0.941414
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.945930 grad_norm=0.063484
# [vqe] iter 4 new best energy=-0.945930
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.948872 grad_norm=0.031042
# [vqe] iter 5 new best energy=-0.948872
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.949784 grad_norm=0.005562
# [vqe] iter 6 new best energy=-0.949784
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.948982 grad_norm=0.029969
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.947431 grad_norm=0.050551
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.946196 grad_norm=0.062322
# [vqe] prepare run: name=lih_6q_custom_R1.4 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.908322 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.908322
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.908322 grad_norm=0.054726
# [vqe] iter 1 new best energy=-0.908322
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.909454 grad_norm=0.120553
# [vqe] iter 2 new best energy=-0.909454
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.914226 grad_norm=0.097847
# [vqe] iter 3 new best energy=-0.914226
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.919022 grad_norm=0.069423
# [vqe] iter 4 new best energy=-0.919022
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.922419 grad_norm=0.038784
# [vqe] iter 5 new best energy=-0.922419
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.923889 grad_norm=0.010401
# [vqe] iter 6 new best energy=-0.923889
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.923560 grad_norm=0.022211
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.922147 grad_norm=0.044019
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.920648 grad_norm=0.058728
# [vqe] prepare run: name=lih_6q_custom_R1.7 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.816127 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.816127
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.816127 grad_norm=0.021652
# [vqe] iter 1 new best energy=-0.816127
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.817256 grad_norm=0.126903
# [vqe] iter 2 new best energy=-0.817256
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.822748 grad_norm=0.107217
# [vqe] iter 3 new best energy=-0.822748
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.828336 grad_norm=0.082412
# [vqe] iter 4 new best energy=-0.828336
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.832646 grad_norm=0.055479
# [vqe] iter 5 new best energy=-0.832646
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.835125 grad_norm=0.029202
# [vqe] iter 6 new best energy=-0.835125
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.835744 grad_norm=0.014309
# [vqe] iter 7 new best energy=-0.835744
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.834974 grad_norm=0.028160
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.833619 grad_norm=0.044253
# [vqe] prepare run: name=lih_6q_custom_R2.0 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.712500 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.712500
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.712500 grad_norm=0.037245
# [vqe] iter 1 new best energy=-0.712500
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.713520 grad_norm=0.135669
# [vqe] iter 2 new best energy=-0.713520
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.719373 grad_norm=0.119772
# [vqe] iter 3 new best energy=-0.719373
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.725809 grad_norm=0.099463
# [vqe] iter 4 new best energy=-0.725809
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.731449 grad_norm=0.076844
# [vqe] iter 5 new best energy=-0.731449
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.735654 grad_norm=0.053289
# [vqe] iter 6 new best energy=-0.735654
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.738156 grad_norm=0.030677
# [vqe] iter 7 new best energy=-0.738156
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.738995 grad_norm=0.015568
# [vqe] iter 8 new best energy=-0.738995
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.738524 grad_norm=0.023152
# [vqe] prepare run: name=lih_6q_custom_R2.3 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.620341 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.620341
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.620341 grad_norm=0.019547
# [vqe] iter 1 new best energy=-0.620341
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.621011 grad_norm=0.145147
# [vqe] iter 2 new best energy=-0.621011
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.627773 grad_norm=0.131913
# [vqe] iter 3 new best energy=-0.627773
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.635268 grad_norm=0.114992
# [vqe] iter 4 new best energy=-0.635268
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.642177 grad_norm=0.095971
# [vqe] iter 5 new best energy=-0.642177
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.647866 grad_norm=0.075846
# [vqe] iter 6 new best energy=-0.647866
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.652005 grad_norm=0.055828
# [vqe] iter 7 new best energy=-0.652005
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.654488 grad_norm=0.038149
# [vqe] iter 8 new best energy=-0.654488
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.655448 grad_norm=0.027689
# [vqe] iter 9 new best energy=-0.655448
# [vqe] prepare run: name=lih_6q_custom_R2.6 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.543897 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.543897
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.543897 grad_norm=0.146076
# [vqe] iter 1 new best energy=-0.543897
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.552679 grad_norm=0.142581
# [vqe] iter 2 new best energy=-0.552679
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.561544 grad_norm=0.127136
# [vqe] iter 3 new best energy=-0.561544
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.569523 grad_norm=0.110234
# [vqe] iter 4 new best energy=-0.569523
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.576154 grad_norm=0.092741
# [vqe] iter 5 new best energy=-0.576154
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.581212 grad_norm=0.075787
# [vqe] iter 6 new best energy=-0.581212
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.584660 grad_norm=0.061010
# [vqe] iter 7 new best energy=-0.584660
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.586664 grad_norm=0.050430
# [vqe] iter 8 new best energy=-0.586664
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.587576 grad_norm=0.045299
# [vqe] iter 9 new best energy=-0.587576
# [vqe] prepare run: name=lih_6q_custom_R2.9 num_qubits=6 model=custom layers=3 shots=4096 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 0 energy=-0.482132 grad_norm=0.000000
# [vqe] iter 0 new best energy=-0.482132
# [vqe] iter 1 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 1 energy=-0.482132 grad_norm=0.152660
# [vqe] iter 1 new best energy=-0.482132
# [vqe] iter 2 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 2 energy=-0.491578 grad_norm=0.148482
# [vqe] iter 2 new best energy=-0.491578
# [vqe] iter 3 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 3 energy=-0.501400 grad_norm=0.134860
# [vqe] iter 3 new best energy=-0.501400
# [vqe] iter 4 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 4 energy=-0.510567 grad_norm=0.119439
# [vqe] iter 4 new best energy=-0.510567
# [vqe] iter 5 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 5 energy=-0.518574 grad_norm=0.102757
# [vqe] iter 5 new best energy=-0.518574
# [vqe] iter 6 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 6 energy=-0.525120 grad_norm=0.085520
# [vqe] iter 6 new best energy=-0.525120
# [vqe] iter 7 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 7 energy=-0.530046 grad_norm=0.068872
# [vqe] iter 7 new best energy=-0.530046
# [vqe] iter 8 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 8 energy=-0.533334 grad_norm=0.054694
# [vqe] iter 8 new best energy=-0.533334
# [vqe] iter 9 start
# MPS tensor shape: torch.Size([1, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 8])
# MPS tensor shape: torch.Size([8, 2, 4])
# MPS tensor shape: torch.Size([4, 2, 2])
# MPS tensor shape: torch.Size([2, 2, 1])
# [vqe] iter 9 energy=-0.535138 grad_norm=0.045613
# [vqe] iter 9 new best energy=-0.535138

# %%
from matplotlib import pyplot as plt

R_values = [res['R'] for res in energy_ucc]
estimated_energies_ucc = [res['e_total'] for res in energy_ucc]
R_range = np.arange(0.5, 3.01, 0.1)
fci_energies = []
for R in R_range:
    json_path = Path(f'data/chemistry/lih_R{R:.1f}_angstrom_sto-3g_6q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))
    fci_energies.append(float(data['fci_energy']))
plt.figure(figsize=(10, 6))
plt.scatter(R_values, estimated_energies_ucc, marker='s', label='Unitary Coupled Cluster Ansatz')
plt.plot(R_range, fci_energies, 'k-', label='FCI Energy')
plt.xlabel('Interatomic Distance R (angstrom)')
plt.ylabel('Energy (Hartree)')
plt.legend()
plt.title('LiH Molecule Energy vs Interatomic Distance')
plt.tick_params(right=True, top=True)
plt.tight_layout()
plt.show()
