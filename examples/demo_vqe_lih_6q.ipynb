# %% [markdown]
# <!-- # LiH 分子 VQE 完整教程（6-Qubit）
#
# 接下来我们考虑LiH分子：
# - 通过 freeze 和 remove，将 LiH 的active space encode 成 6-qubit 哈密顿量
# - 构建一个 UCC-style 参数化电路
# - 使用 VQE 进行参数优化并与 FCI 基准比较 -->

# %% [markdown]
# ## 1. 参数配置与运行建议

# %%
from pathlib import Path
import json
import math

# Geometry / chemistry config
R = 2.2
R_UNIT = 'angstrom'
BASIS = 'sto-3g'
MULTIPLICITY = 1
CHARGE = 0

# VQE config
cfg = {
    'layers': 3,
    'shots': 4096,
    'max_iters': 20,
    'learning_rate': 0.03,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2,
}

print('R =', R, R_UNIT)
print('Basis =', BASIS)
print('VQE cfg =', cfg)
# Out:
# R = 2.2 angstrom
# Basis = sto-3g
# VQE cfg = {'layers': 3, 'shots': 4096, 'max_iters': 20, 'learning_rate': 0.03, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %% [markdown]
# ## 2. 读取 WSL 导出的 6-qubit 哈密顿量系数
#
# For the LiH molecule in the **STO-3G basis**, with frozen 1a1 and removed 1e1, 2e1, there are **6 spin orbitals**, which map to **6 qubits** after fermion-to-qubit transformation (e.g., Jordan–Wigner).
#
# 默认读取文件：
# - `data/chemistry/lih_R2.2_sto-3g_6q.json`
#
# 若文件不存在，请在 WSL 中执行：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_lih.sh 2.2 angstrom
# ```

# %%
from __future__ import annotations

import os
import json
from pathlib import Path

# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner

json_path = Path('data/chemistry/lih_R2.2_angstrom_sto-3g_6q.json')
data = json.loads(json_path.read_text(encoding='utf-8'))

lih_constant = float(data['constant'])
lih_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded from:', json_path)
print('nqubits:', nqubits)
print('term_count:', len(lih_6q_terms))
print('fci_energy:', fci_energy)
# Out:
# Loaded from: data\chemistry\lih_R2.2_angstrom_sto-3g_6q.json
# nqubits: 6
# term_count: 117
# fci_energy: -7.845683623197186

# %% [markdown]
# ## 3. 构建 LiH 专用 UCC-style Custom Ansatz
#
# 结合对称性限制和激发能量，只考虑UCC中的最关键项，包括
#
# $$
# a_5^\dagger a_2^\dagger a_1 a_0, \quad a_4^\dagger a_3^\dagger a_1 a_0, \quad a_5^\dagger a_4^\dagger a_1 a_0
# $$
#
# 对应的UCC为
#
# $$
# U(\theta) =
# \exp\left[
# -i\theta_3 Y_0X_1Z_2Z_3X_4Y_5 -i\theta_2 Y_0X_1Z_2X_3Y_4 -i\theta_1 Y_0 X_1 X_2 Z_3 Z_4 Y_5
# \right]
# $$

# %%
from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.circuit import QuantumCircuit

def build_h2_ucc_style_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(6)

    # -------------------------
    # Hartree–Fock reference or "singlet" reference state preparation
    # |110000> or (|110000> - |001100>)/sqrt(2)
    # -------------------------

    qc.ry("theta_0", 0)
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)

    qc.x(0)
    qc.x(1)

    qc.pauli_evolution("theta_1", "X0 X1 Y2 Z3 Z4 X5")
    qc.pauli_evolution("theta_2", "X0 X1 Z2 Y3 X4")
    qc.pauli_evolution("theta_3", "X0 X1 Z2 Z3 Y4 X5")
    return qc

custom_ansatz_qc = build_h2_ucc_style_symbolic_ansatz()
symbolic_params = sorted(
    [k for k, v in custom_ansatz_qc.params_value.items() if isinstance(k, str) and isinstance(v, str)]
)
print('Total gates in custom H2-UCC-style ansatz:', len(custom_ansatz_qc.gates))
# Out:
# Total gates in custom H2-UCC-style ansatz: 67

# %% [markdown]
# ## 4. 运行 VQE 并验证 Ansatz
#
# 通常来说，加入更强问题结构先验的 ansatz，往往在相同预算下能得到更低误差，但并不绝对。

# %%
runner = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
)

kwargs = {
    'name': f'lih_6q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0]*len(symbolic_params),
}

res = runner.run_model(**kwargs)
e_total = lih_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 6-Qubit LiH VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=lih_6q_custom num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.649336 grad_norm=0.148236
# [vqe] iter 0 new best energy=-0.649336
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.656303 grad_norm=0.134752
# [vqe] iter 1 new best energy=-0.656303
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.662383 grad_norm=0.120923
# [vqe] iter 2 new best energy=-0.662383
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.667532 grad_norm=0.106849
# [vqe] iter 3 new best energy=-0.667532
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.671723 grad_norm=0.092756
# [vqe] iter 4 new best energy=-0.671723
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.674978 grad_norm=0.079037
# [vqe] iter 5 new best energy=-0.674978
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.677371 grad_norm=0.066283
# [vqe] iter 6 new best energy=-0.677371
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.679019 grad_norm=0.055295
# [vqe] iter 7 new best energy=-0.679019
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.680066 grad_norm=0.046931
# [vqe] iter 8 new best energy=-0.680066
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.680685 grad_norm=0.041612
# [vqe] iter 9 new best energy=-0.680685
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.681058 grad_norm=0.038811
# [vqe] iter 10 new best energy=-0.681058
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.681333 grad_norm=0.037304
# [vqe] iter 11 new best energy=-0.681333
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.681596 grad_norm=0.035988
# [vqe] iter 12 new best energy=-0.681596
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.681872 grad_norm=0.034314
# [vqe] iter 13 new best energy=-0.681872
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.682146 grad_norm=0.032229
# [vqe] iter 14 new best energy=-0.682146
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.682390 grad_norm=0.029975
# [vqe] iter 15 new best energy=-0.682390
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.682576 grad_norm=0.027931
# [vqe] iter 16 new best energy=-0.682576
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.682689 grad_norm=0.026496
# [vqe] iter 17 new best energy=-0.682689
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.682721 grad_norm=0.025978
# [vqe] iter 18 new best energy=-0.682721
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.682674 grad_norm=0.026472
# === 6-Qubit LiH VQE Result ===
# Estimated total energy:   -7.841379
# FCI reference energy:     -7.84568362
# Absolute error vs FCI:    0.00430463

# %% [markdown]
# ## 5. 在真实硬件上运行线路

# %%
cfg['prefer_chips'] = 'Dongling'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
cfg['gradient_method'] = 'parameter-shift'

runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    clifford_fitting=cfg['clifford_fitting'],
    clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
)

kwargs = {
    'name': f'h2_4q_cmp_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': lih_6q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
}

res = runner_cmp.run_model(**kwargs)
e_total = lih_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 4-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + lih_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_4q_cmp_custom num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# Dongling configuration loading done!
# The last calibration time was 2026-03-12 22:31:23
# [vqe] candidate chips: ['Dongling']
# Dongling configuration loading done!
# The last calibration time was 2026-03-12 22:31:23
# [vqe] running on chip: Dongling
# [vqe] clifford fitting prepared: terms=117 samples=8
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=parameter-shift
# [vqe] iter 0 start
# [vqe] iter 0 energy=0.173081 grad_norm=0.283906
# [vqe] iter 0 new best energy=0.173081
# [vqe] iter 1 start
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File d:\Programs\Miniconda\envs\quantum\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File d:\Programs\Miniconda\envs\quantum\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File d:\Programs\Miniconda\envs\quantum\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\util\retry.py:490, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     489 if read is False or method is None or not self._is_method_retryable(method):
# --> 490     raise reraise(type(error), error, _stacktrace)
#     491 elif read is not None:
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File d:\Programs\Miniconda\envs\quantum\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File d:\Programs\Miniconda\envs\quantum\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File d:\Programs\Miniconda\envs\quantum\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:995, in VQERunner.run_model(self, name, num_qubits, model, model_params, hamiltonian, target_qubits, init_params, callback, prefer_chips, rank_weights, ansatz, custom_ansatz_circuit)
#     994     print("[vqe] running on chip:", chip_name)
# --> 995     return run_vqe_with_backend(
#     996         self.client,
#     997         name=name,
#     998         num_qubits=num_qubits,
#     999         backend=backend,
#    1000         chip_name=chip_name,
#    1001         hamiltonian=hamiltonian,
#    1002         layers=self.layers,
#    1003         shots=self.shots,
#    1004         max_iters=self.max_iters,
#    1005         learning_rate=self.learning_rate,
#    1006         beta1=self.beta1,
#    1007         beta2=self.beta2,
#    1008         eps=self.eps,
#    1009         shift=self.shift,
#    1010         zne=self.zne,
#    1011         readout_mitigation=self.readout_mitigation,
#    1012         target_qubits=target_qubits,
#    1013         seed=self.seed,
#    1014         init_params=init_params,
#    1015         callback=callback,
#    1016         gradient_method=self.gradient_method,
#    1017         ansatz=run_ansatz,
#    1018         custom_ansatz_circuit=custom_ansatz_circuit,
#    1019         clifford_fitting=self.clifford_fitting,
#    1020         clifford_fitting_num_samples=self.clifford_fitting_num_samples,
#    1021     )
#    1022 except Exception as exc:
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:859, in run_vqe_with_backend(client, name, num_qubits, backend, chip_name, hamiltonian, layers, shots, max_iters, learning_rate, beta1, beta2, eps, shift, zne, readout_mitigation, target_qubits, seed, init_params, callback, gradient_method, ansatz, custom_ansatz_circuit, clifford_fitting, clifford_fitting_num_samples)
#     846     energy, expectations = _evaluate_energy_with_backend(
#     847         client,
#     848         qc,
#    (...)
#     857         clifford_fit_map=clifford_fit_map,
#     858     )
# --> 859     grads = _parameter_shift_gradient(
#     860         client,
#     861         params,
#     862         name=f"{name}_iter{it}",
#     863         num_qubits=num_qubits,
#     864         backend=backend,
#     865         chip_name=chip_name,
#     866         shots=shots,
#     867         hamiltonian=hamiltonian,
#     868         shift=shift,
#     869         zne=zne,
#     870         readout_mitigation=readout_mitigation,
#     871         transpiled_template=transpiled_template,
#     872         param_names=param_names,
#     873         clifford_fit_map=clifford_fit_map,
#     874     )
#     876 grad_norm = float(np.linalg.norm(grads))
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:680, in _parameter_shift_gradient(client, params, name, num_qubits, backend, chip_name, shots, hamiltonian, shift, zne, readout_mitigation, transpiled_template, param_names, clifford_fit_map)
#     667 e_plus, _ = _evaluate_energy_with_backend(
#     668     client,
#     669     qc_plus,
#    (...)
#     678     clifford_fit_map=clifford_fit_map,
#     679 )
# --> 680 e_minus, _ = _evaluate_energy_with_backend(
#     681     client,
#     682     qc_minus,
#     683     name=f"{name}_grad_m{i}",
#     684     num_qubits=num_qubits,
#     685     backend=backend,
#     686     chip_name=chip_name,
#     687     shots=shots,
#     688     hamiltonian=hamiltonian,
#     689     zne=zne,
#     690     readout_mitigation=readout_mitigation,
#     691     clifford_fit_map=clifford_fit_map,
#     692 )
#     693 grads[i] = 0.5 * (e_plus - e_minus)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:614, in _evaluate_energy_with_backend(client, qc, name, num_qubits, backend, chip_name, shots, hamiltonian, zne, readout_mitigation, clifford_fit_map)
#     613 observables = [term[1] for term in hamiltonian]
# --> 614 result = client._run_with_backend(
#     615     qc,
#     616     name,
#     617     num_qubits,
#     618     backend=backend,
#     619     chip_name=chip_name,
#     620     shots=shots,
#     621     zne=zne,
#     622     readout_mitigation=readout_mitigation,
#     623     observables=observables,
#     624     return_probabilities=False,
#     625     print_true=False,
#     626     transpile=False,
#     627 )
#     628 expectations_raw = _ensure_observable_map(observables, result.observable_values)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\client.py:342, in QuantumHardwareClient._run_with_backend(self, qc, name, num_qubits, backend, chip_name, shots, zne, readout_mitigation, readout_shots, observables, return_probabilities, target_qubits, merge_groups, qasm_version, print_true, transpile)
#     341 for gi, scale, task_id in pending:
# --> 342 	status = self._wait_task(task_id)
#     343 	if status != "Finished":
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\client.py:147, in QuantumHardwareClient._wait_task(self, task_id)
#     146 while True:
# --> 147 	status = self.tmgr.status(task_id)
#     148 	if status in {"Finished", "Failed", "Canceled"}:
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\task.py:89, in Task.status(self, tid)
#      88 time.sleep(0.2)
# ---> 89 return self.request(f'{self.URL}/task/status/{tid}')
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\task.py:51, in Task.request(self, url, data, method)
#      50 if method == 'get':
# ---> 51     res = self.session.get(url, headers={'token': self.token})
#      52 elif method == 'post':
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File d:\Programs\Miniconda\envs\quantum\lib\site-packages\requests\adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[151], line 33
#       8 runner_cmp = VQERunner(
#       9     client=QuantumHardwareClient(),
#      10     layers=cfg['layers'],
#    (...)
#      20     clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
#      21 )
#      23 kwargs = {
#      24     'name': f'h2_4q_cmp_custom',
#      25     'num_qubits': nqubits,
#    (...)
#      30     'prefer_chips': cfg['prefer_chips'],
#      31 }
# ---> 33 res = runner_cmp.run_model(**kwargs)
#      34 e_total = lih_constant + res.best_energy
#      35 abs_error_fci = abs(e_total - fci_energy)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:1026, in VQERunner.run_model(self, name, num_qubits, model, model_params, hamiltonian, target_qubits, init_params, callback, prefer_chips, rank_weights, ansatz, custom_ansatz_circuit)
#    1023         last_error = exc
#    1024         continue
# -> 1026 raise RuntimeError("all candidate chips failed to run VQE") from last_error
#
# RuntimeError: all candidate chips failed to run VQE

# %%
R_range = np.arange(0.5, 3.01, 0.3)
energy_ucc = []
for r, R in enumerate(R_range):
    json_path = Path(f'data/chemistry/lih_R{R:.1f}_angstrom_sto-3g_6q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))

    lih_constant = float(data['constant'])
    lih_6q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
    nqubits = int(data['nqubits'])
    fci_energy = float(data['fci_energy'])

    runner = VQERunner(
        client=QuantumHardwareClient(),
        layers=cfg['layers'],
        shots=cfg['shots'],
        max_iters=cfg['max_iters'],
        learning_rate=cfg['learning_rate'],
        gradient_method=cfg['gradient_method'],
        seed=cfg['seed'],
        shift=cfg['shift'],
    )

    kwargs = {
        'name': f'lih_6q_custom_R{R:.1f}',
        'num_qubits': nqubits,
        'model': 'custom',
        'hamiltonian': lih_6q_terms,
        'ansatz': 'custom',
        'custom_ansatz_circuit': custom_ansatz_qc,
        'prefer_chips': cfg['prefer_chips'],
        'init_params': [0]*len(symbolic_params),
    }

    res = runner.run_model(**kwargs)
    e_total = lih_constant + res.best_energy
    abs_error_fci = abs(e_total - fci_energy)
    energy_ucc.append({
        'R': R,
        'e_total': e_total,
    })
# Out:
# [vqe] prepare run: name=lih_6q_custom_R0.5 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.945388 grad_norm=0.114512
# [vqe] iter 0 new best energy=-0.945388
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.955215 grad_norm=0.038537
# [vqe] iter 1 new best energy=-0.955215
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.953933 grad_norm=0.045042
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.952388 grad_norm=0.068681
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.953044 grad_norm=0.067266
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.954151 grad_norm=0.053873
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.954915 grad_norm=0.036061
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.955302 grad_norm=0.021941
# [vqe] iter 7 new best energy=-0.955302
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.955282 grad_norm=0.026660
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.955013 grad_norm=0.038328
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.954898 grad_norm=0.043428
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.955164 grad_norm=0.039479
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.955577 grad_norm=0.028819
# [vqe] iter 12 new best energy=-0.955577
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.955779 grad_norm=0.017582
# [vqe] iter 13 new best energy=-0.955779
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.955729 grad_norm=0.016303
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.955639 grad_norm=0.022700
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.955693 grad_norm=0.026647
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.955877 grad_norm=0.026007
# [vqe] iter 17 new best energy=-0.955877
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.956026 grad_norm=0.022131
# [vqe] iter 18 new best energy=-0.956026
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.956043 grad_norm=0.017372
# [vqe] iter 19 new best energy=-0.956043
# [vqe] prepare run: name=lih_6q_custom_R0.8 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.882739 grad_norm=0.128862
# [vqe] iter 0 new best energy=-0.882739
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.893815 grad_norm=0.065208
# [vqe] iter 1 new best energy=-0.893815
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.895818 grad_norm=0.038770
# [vqe] iter 2 new best energy=-0.895818
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.895644 grad_norm=0.046502
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.894161 grad_norm=0.065060
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.892959 grad_norm=0.074717
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.893305 grad_norm=0.070839
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.895177 grad_norm=0.053433
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.897063 grad_norm=0.027551
# [vqe] iter 8 new best energy=-0.897063
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.897708 grad_norm=0.006114
# [vqe] iter 9 new best energy=-0.897708
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.897110 grad_norm=0.025668
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.896176 grad_norm=0.040714
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.895706 grad_norm=0.047175
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.895885 grad_norm=0.046316
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.896393 grad_norm=0.040272
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.896872 grad_norm=0.031401
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.897232 grad_norm=0.021566
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.897485 grad_norm=0.013727
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.897523 grad_norm=0.015384
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.897293 grad_norm=0.023565
# [vqe] prepare run: name=lih_6q_custom_R1.1 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.935515 grad_norm=0.129554
# [vqe] iter 0 new best energy=-0.935515
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.946600 grad_norm=0.062575
# [vqe] iter 1 new best energy=-0.946600
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.947995 grad_norm=0.042517
# [vqe] iter 2 new best energy=-0.947995
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.947378 grad_norm=0.054501
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.946206 grad_norm=0.069443
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.945495 grad_norm=0.075619
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.946015 grad_norm=0.069890
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.947878 grad_norm=0.050529
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.949621 grad_norm=0.022530
# [vqe] iter 8 new best energy=-0.949621
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.950025 grad_norm=0.009788
# [vqe] iter 9 new best energy=-0.950025
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.949212 grad_norm=0.032668
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.948196 grad_norm=0.046899
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.947833 grad_norm=0.050956
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.948279 grad_norm=0.046427
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.949058 grad_norm=0.036183
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.949599 grad_norm=0.024451
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.949757 grad_norm=0.016780
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.949726 grad_norm=0.017639
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.949618 grad_norm=0.023525
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.949434 grad_norm=0.029349
# [vqe] prepare run: name=lih_6q_custom_R1.4 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.908322 grad_norm=0.131120
# [vqe] iter 0 new best energy=-0.908322
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.920493 grad_norm=0.065386
# [vqe] iter 1 new best energy=-0.920493
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.922123 grad_norm=0.043262
# [vqe] iter 2 new best energy=-0.922123
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.921559 grad_norm=0.052810
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.920600 grad_norm=0.065727
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.919941 grad_norm=0.072403
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.919978 grad_norm=0.070884
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.921267 grad_norm=0.058101
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.923111 grad_norm=0.035714
# [vqe] iter 8 new best energy=-0.923111
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.924228 grad_norm=0.011262
# [vqe] iter 9 new best energy=-0.924228
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.924084 grad_norm=0.019500
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.923090 grad_norm=0.037994
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.922195 grad_norm=0.048231
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.922115 grad_norm=0.049242
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.922783 grad_norm=0.042495
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.923592 grad_norm=0.031081
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.924050 grad_norm=0.019501
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.924110 grad_norm=0.014807
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.923964 grad_norm=0.019667
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.923784 grad_norm=0.025912
# [vqe] prepare run: name=lih_6q_custom_R1.7 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.816127 grad_norm=0.135752
# [vqe] iter 0 new best energy=-0.816127
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.830579 grad_norm=0.076436
# [vqe] iter 1 new best energy=-0.830579
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.834019 grad_norm=0.043939
# [vqe] iter 2 new best energy=-0.834019
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.833777 grad_norm=0.047021
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.833102 grad_norm=0.056378
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.832346 grad_norm=0.064484
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.831814 grad_norm=0.068665
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.831864 grad_norm=0.067245
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.832979 grad_norm=0.057439
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.834728 grad_norm=0.039833
# [vqe] iter 9 new best energy=-0.834728
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.836110 grad_norm=0.018634
# [vqe] iter 10 new best energy=-0.836110
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.836490 grad_norm=0.009404
# [vqe] iter 11 new best energy=-0.836490
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.835872 grad_norm=0.026030
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.834854 grad_norm=0.039263
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.834227 grad_norm=0.045520
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.834369 grad_norm=0.044761
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.835042 grad_norm=0.038423
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.835768 grad_norm=0.028753
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.836212 grad_norm=0.018854
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.836307 grad_norm=0.014198
# [vqe] prepare run: name=lih_6q_custom_R2.0 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.712500 grad_norm=0.142799
# [vqe] iter 0 new best energy=-0.712500
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.729990 grad_norm=0.091418
# [vqe] iter 1 new best energy=-0.729990
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.736580 grad_norm=0.050513
# [vqe] iter 2 new best energy=-0.736580
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.736876 grad_norm=0.046982
# [vqe] iter 3 new best energy=-0.736876
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.736460 grad_norm=0.053499
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.736167 grad_norm=0.056987
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.735768 grad_norm=0.060087
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.735399 grad_norm=0.062457
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.735173 grad_norm=0.063431
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.735510 grad_norm=0.060825
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.736732 grad_norm=0.051921
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.738421 grad_norm=0.036830
# [vqe] iter 11 new best energy=-0.738421
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.739743 grad_norm=0.019019
# [vqe] iter 12 new best energy=-0.739743
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.740169 grad_norm=0.010347
# [vqe] iter 13 new best energy=-0.740169
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.739744 grad_norm=0.022028
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.738897 grad_norm=0.033181
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.738145 grad_norm=0.039628
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.737871 grad_norm=0.041177
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.738200 grad_norm=0.038243
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.738922 grad_norm=0.031699
# [vqe] prepare run: name=lih_6q_custom_R2.3 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.620341 grad_norm=0.151073
# [vqe] iter 0 new best energy=-0.620341
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.641353 grad_norm=0.106979
# [vqe] iter 1 new best energy=-0.641353
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.652191 grad_norm=0.062394
# [vqe] iter 2 new best energy=-0.652191
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.654259 grad_norm=0.045357
# [vqe] iter 3 new best energy=-0.654259
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.652982 grad_norm=0.059223
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.652680 grad_norm=0.064480
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.653272 grad_norm=0.060519
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.653664 grad_norm=0.056060
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.653597 grad_norm=0.054929
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.653375 grad_norm=0.055212
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.653250 grad_norm=0.055395
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.653501 grad_norm=0.054296
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.654330 grad_norm=0.050203
# [vqe] iter 12 new best energy=-0.654330
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.655648 grad_norm=0.041845
# [vqe] iter 13 new best energy=-0.655648
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.657046 grad_norm=0.029478
# [vqe] iter 14 new best energy=-0.657046
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.657991 grad_norm=0.015923
# [vqe] iter 15 new best energy=-0.657991
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.658137 grad_norm=0.012927
# [vqe] iter 16 new best energy=-0.658137
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.657552 grad_norm=0.023823
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.656684 grad_norm=0.033687
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.656060 grad_norm=0.038722
# [vqe] prepare run: name=lih_6q_custom_R2.6 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.543897 grad_norm=0.159766
# [vqe] iter 0 new best energy=-0.543897
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.568787 grad_norm=0.121828
# [vqe] iter 1 new best energy=-0.568787
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.584729 grad_norm=0.076167
# [vqe] iter 2 new best energy=-0.584729
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.590255 grad_norm=0.039999
# [vqe] iter 3 new best energy=-0.590255
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.588135 grad_norm=0.058391
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.585149 grad_norm=0.081469
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.585100 grad_norm=0.084783
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.587285 grad_norm=0.073248
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.589688 grad_norm=0.055930
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.590869 grad_norm=0.043365
# [vqe] iter 9 new best energy=-0.590869
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.590659 grad_norm=0.041983
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.589823 grad_norm=0.046179
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.589156 grad_norm=0.049445
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.589086 grad_norm=0.050021
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.589686 grad_norm=0.047856
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.590778 grad_norm=0.043135
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.592042 grad_norm=0.036111
# [vqe] iter 16 new best energy=-0.592042
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.593139 grad_norm=0.027304
# [vqe] iter 17 new best energy=-0.593139
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.593804 grad_norm=0.018165
# [vqe] iter 18 new best energy=-0.593804
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.593902 grad_norm=0.013509
# [vqe] iter 19 new best energy=-0.593902
# [vqe] prepare run: name=lih_6q_custom_R2.9 num_qubits=6 model=custom layers=3 shots=4096 max_iters=20
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=20 layers=3 params=4 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.482132 grad_norm=0.168355
# [vqe] iter 0 new best energy=-0.482132
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.511001 grad_norm=0.135666
# [vqe] iter 1 new best energy=-0.511001
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.532078 grad_norm=0.091092
# [vqe] iter 2 new best energy=-0.532078
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.542676 grad_norm=0.037646
# [vqe] iter 3 new best energy=-0.542676
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.542039 grad_norm=0.041968
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.535317 grad_norm=0.088637
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.530749 grad_norm=0.111895
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.531371 grad_norm=0.110744
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.535502 grad_norm=0.092625
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.540341 grad_norm=0.065208
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.543738 grad_norm=0.035721
# [vqe] iter 10 new best energy=-0.543738
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.544785 grad_norm=0.016619
# [vqe] iter 11 new best energy=-0.544785
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.543804 grad_norm=0.027917
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.541875 grad_norm=0.043454
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.540143 grad_norm=0.053538
# [vqe] iter 15 start
# [vqe] iter 15 energy=-0.539333 grad_norm=0.057792
# [vqe] iter 16 start
# [vqe] iter 16 energy=-0.539646 grad_norm=0.056803
# [vqe] iter 17 start
# [vqe] iter 17 energy=-0.540869 grad_norm=0.051198
# [vqe] iter 18 start
# [vqe] iter 18 energy=-0.542552 grad_norm=0.041569
# [vqe] iter 19 start
# [vqe] iter 19 energy=-0.544158 grad_norm=0.028657

# %%
from matplotlib import pyplot as plt

R_values = [res['R'] for res in energy_ucc]
estimated_energies_ucc = [res['e_total'] for res in energy_ucc]
R_range = np.arange(0.5, 3.01, 0.1)
fci_energies = []
for R in R_range:
    json_path = Path(f'data/chemistry/lih_R{R:.1f}_angstrom_sto-3g_6q.json')
    data = json.loads(json_path.read_text(encoding='utf-8'))
    fci_energies.append(float(data['fci_energy']))
plt.figure(figsize=(10, 6))
plt.scatter(R_values, estimated_energies_ucc, marker='s', label='Unitary Coupled Cluster Ansatz')
plt.plot(R_range, fci_energies, 'k-', label='FCI Energy')
plt.xlabel('Interatomic Distance R (angstrom)')
plt.ylabel('Energy (Hartree)')
plt.legend()
plt.title('LiH Molecule Energy vs Interatomic Distance')
plt.tick_params(right=True, top=True)
plt.tight_layout()
plt.show()
