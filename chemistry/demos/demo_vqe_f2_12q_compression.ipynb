# %% [markdown]
# # F2 12Q VQE: Circuit Compression Demo
#
# This notebook demonstrates VQE under `gradient_method="parameter-shift"` with hybrid MPS/MPO circuit compression.
#
# Comparison items:
# - Baseline: no compression
# - Compression: suffix block planning + local recompression

# %%
# from __future__ import annotations

import os
import json
import math
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.algorithms.circuit_compression import plan_hybrid_suffix_blocks
from quantum_hw.circuit import QuantumCircuit

# %%
# ===== 1) Load F2 12-qubit Hamiltonian =====
json_path = Path('../data/f2_R2.6_angstrom_sto-3g_12q.json')
data = json.loads(json_path.read_text(encoding='utf-8'))

f2_constant = float(data['constant'])
f2_12q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])

print('Loaded:', json_path)
print('nqubits =', nqubits, 'term_count =', len(f2_12q_terms))
print('fci_energy =', fci_energy)
# Out:
# Loaded: data\chemistry\f2_R2.6_angstrom_sto-3g_12q.json
# nqubits = 12 term_count = 382
# fci_energy = -195.9734686096283

# %%
# ===== 2) Build the same LiH custom ansatz style used in existing demo =====
def build_f2_symbolic_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(12)

    # HF state or "singlet" reference state
    qc.ry("theta_0", 8)
    qc.cx(8, 9)
    qc.cx(9, 10)
    qc.cx(10, 11)

    for q in range(10):
        qc.x(q)

    qc.pauli_evolution("theta_1", "Y0 X1 Z2 Z3 Z4 Z5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_2", "Y2 X3 Z4 Z5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_3", "Y4 X5 Z6 Z7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_4", "Y6 X7 Z8 Z9 X10 Y11")
    qc.pauli_evolution("theta_5", "Y8 X9 X10 Y11")

    return qc


custom_ansatz_qc = build_f2_symbolic_ansatz()
symbolic_params = sorted([
    k for k, v in custom_ansatz_qc.params_value.items()
    if isinstance(k, str) and isinstance(v, str)
])

print('custom gate count =', len(custom_ansatz_qc.gates))
print('symbolic params =', symbolic_params)
# Out:
# custom gate count = 149
# symbolic params = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5']

# %%
# ===== 3) Shared VQE config (parameter-shift) =====
cfg = {
    'layers': 3,
    'shots': 1024,
    'max_iters': 10,
    'learning_rate': 0.2,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2.0,
}

base_kwargs = {
    'name': 'f2_12q_custom_compress_demo',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': f2_12q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01] * len(symbolic_params),
    'target_qubits': list(range(1, nqubits+1)),
}

print(cfg)
# Out:
# {'layers': 3, 'shots': 1024, 'max_iters': 10, 'learning_rate': 0.2, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %%
# ===== 4) Baseline run: no compression =====
runner_base = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
    enable_circuit_compression=False,
)

res_base = runner_base.run_model(**base_kwargs)
e_total_base = f2_constant + res_base.best_energy
err_base = abs(e_total_base - fci_energy)

print('Baseline best_total =', round(e_total_base, 8))
print('Baseline abs_error_vs_fci =', round(err_base, 8))
# Out:
# [vqe] prepare run: name=f2_12q_custom_compress_demo num_qubits=12 model=custom layers=3 shots=1024 max_iters=10
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=10 layers=3 params=6 ansatz=custom shots=1024 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-5.620472 grad_norm=0.392761
# [vqe] iter 0 new best energy=-5.620472
# [vqe] iter 1 start
# [vqe] iter 1 energy=-5.670816 grad_norm=0.383714
# [vqe] iter 1 new best energy=-5.670816
# [vqe] iter 2 start
# [vqe] iter 2 energy=-5.769930 grad_norm=0.354465
# [vqe] iter 2 new best energy=-5.769930
# [vqe] iter 3 start
# [vqe] iter 3 energy=-5.828485 grad_norm=0.319129
# [vqe] iter 3 new best energy=-5.828485
# [vqe] iter 4 start
# [vqe] iter 4 energy=-5.873118 grad_norm=0.298975
# [vqe] iter 4 new best energy=-5.873118
# [vqe] iter 5 start
# [vqe] iter 5 energy=-5.933159 grad_norm=0.226693
# [vqe] iter 5 new best energy=-5.933159
# [vqe] iter 6 start
# [vqe] iter 6 energy=-5.970465 grad_norm=0.146742
# [vqe] iter 6 new best energy=-5.970465
# [vqe] iter 7 start
# [vqe] iter 7 energy=-5.971610 grad_norm=0.230774
# [vqe] iter 7 new best energy=-5.971610
# [vqe] iter 8 start
# [vqe] iter 8 energy=-5.984064 grad_norm=0.192036
# [vqe] iter 8 new best energy=-5.984064
# [vqe] iter 9 start
# [vqe] iter 9 energy=-5.991880 grad_norm=0.056213
# [vqe] iter 9 new best energy=-5.991880
# Baseline best_total = -195.96840422
# Baseline abs_error_vs_fci = 0.00506439

# %%
# ===== 5) Compression run: enable planner + compression =====
cfg['gradient_method'] = "parameter-shift"
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
    enable_circuit_compression=True,
    compression_block_layers=6,
)

res_cmp = runner_cmp.run_model(**base_kwargs)
e_total_cmp = f2_constant + res_cmp.best_energy
err_cmp = abs(e_total_cmp - fci_energy)

print('Compressed best_total =', round(e_total_cmp, 8))
print('Compressed abs_error_vs_fci =', round(err_cmp, 8))

# %%
# ===== 6) Compare convergence curves =====
plt.figure(figsize=(7, 4))
plt.plot(np.array(res_base.energy_history) + f2_constant, marker='o', ms=3, label='baseline')
plt.plot(np.array(res_cmp.energy_history) + f2_constant, marker='s', ms=3, label='compressed')
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI')
plt.xlabel('Iteration')
plt.ylabel('Total Energy (Hartree)')
plt.title('F2 12Q VQE: baseline vs compression')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

print('--- Summary ---')
print('Baseline total energy   :', round(e_total_base, 8))
print('Compressed total energy :', round(e_total_cmp, 8))
print('Baseline |E-FCI|        :', round(err_base, 8))
print('Compressed |E-FCI|      :', round(err_cmp, 8))
# Out:
# --- Summary ---
# Baseline total energy   : -195.96840422
# Compressed total energy : -195.9903876
# Baseline |E-FCI|        : 0.00506439
# Compressed |E-FCI|      : 0.01691899

# %%
# ===== 7) Run experiments =====
cfg['prefer_chips'] = 'Baihua'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
cfg['gradient_method'] = "parameter-shift"
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    # clifford_fitting=cfg['clifford_fitting'],
    # clifford_fitting_num_samples=cfg['clifford_fitting_num_samples'],
    enable_circuit_compression=True,
    compression_block_layers=6,
)

exp_kwargs = {
    'name': 'f2_12q_custom_compress_demo',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': f2_12q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_ansatz_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01] * len(symbolic_params),
}

res_cmp = runner_cmp.run_model(**exp_kwargs)
e_total_cmp = f2_constant + res_cmp.best_energy
err_cmp = abs(e_total_cmp - fci_energy)

print('=== 12-Qubit F2 VQE Result ===')
print('Compressed best_total =', round(e_total_cmp, 8))
print('Compressed abs_error_vs_fci =', round(err_cmp, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res_cmp.energy_history) + f2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'F2 VQE Convergence (R=2.6)')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=f2_12q_custom_compress_demo num_qubits=12 model=custom layers=3 shots=1024 max_iters=10
# Baihua configuration loading done!
# The last calibration time was 2026-03-19 10:35:13
# [vqe] candidate chips: ['Baihua']
# Baihua configuration loading done!
# The last calibration time was 2026-03-19 10:35:13
# [vqe] running on chip: Baihua
# [vqe] start optimization: iters=10 layers=3 params=6 ansatz=custom shots=1024 shift=1.5707963267948966 gradient=parameter-shift
# [vqe] iter 0 start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 36
#       8 runner_cmp = VQERunner(
#       9     client=QuantumHardwareClient(),
#      10     layers=cfg['layers'],
#    (...)
#      22     compression_block_layers=6,
#      23 )
#      25 exp_kwargs = {
#      26     'name': 'f2_12q_custom_compress_demo',
#      27     'num_qubits': nqubits,
#    (...)
#      33     'init_params': [0.01] * len(symbolic_params),
#      34 }
# ---> 36 res_cmp = runner_cmp.run_model(**exp_kwargs)
#      37 e_total_cmp = f2_constant + res_cmp.best_energy
#      38 err_cmp = abs(e_total_cmp - fci_energy)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:1140, in VQERunner.run_model(self, name, num_qubits, model, model_params, hamiltonian, target_qubits, init_params, callback, prefer_chips, rank_weights, ansatz, custom_ansatz_circuit)
#    1138 try:
#    1139     print("[vqe] running on chip:", chip_name)
# -> 1140     return run_vqe_with_backend(
#    1141         self.client,
#    1142         name=name,
#    1143         num_qubits=num_qubits,
#    1144         backend=backend,
#    1145         chip_name=chip_name,
#    1146         hamiltonian=hamiltonian,
#    1147         layers=self.layers,
#    1148         shots=self.shots,
#    1149         max_iters=self.max_iters,
#    1150         learning_rate=self.learning_rate,
#    1151         beta1=self.beta1,
#    1152         beta2=self.beta2,
#    1153         eps=self.eps,
#    1154         shift=self.shift,
#    1155         zne=self.zne,
#    1156         readout_mitigation=self.readout_mitigation,
#    1157         target_qubits=target_qubits,
#    1158         seed=self.seed,
#    1159         init_params=init_params,
#    1160         callback=callback,
#    1161         gradient_method=self.gradient_method,
#    1162         ansatz=ansatz,
#    1163         custom_ansatz_circuit=custom_ansatz_circuit,
#    1164         clifford_fitting=self.clifford_fitting,
#    1165         clifford_fitting_num_samples=self.clifford_fitting_num_samples,
#    1166         clifford_fitting_num_non_clifford_gates=self.clifford_fitting_num_non_clifford_gates,
#    1167         enable_block_planner=self.enable_block_planner,
#    1168         planner_bond_cap=self.planner_bond_cap,
#    1169         planner_trunc_tol=self.planner_trunc_tol,
#    1170         planner_max_layers_per_block=self.planner_max_layers_per_block,
#    1171         enable_circuit_compression=self.enable_circuit_compression,
#    1172         compression_block_layers=self.compression_block_layers,
#    1173         compression_optimizer_steps=self.compression_optimizer_steps,
#    1174         compression_optimizer_lr=self.compression_optimizer_lr,
#    1175         compression_verbose=self.compression_verbose,
#    1176         compression_plot_loss=self.compression_plot_loss,
#    1177     )
#    1178 except Exception as exc:
#    1179     last_error = exc
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:978, in run_vqe_with_backend(client, name, num_qubits, backend, chip_name, hamiltonian, layers, shots, max_iters, learning_rate, beta1, beta2, eps, shift, zne, readout_mitigation, target_qubits, seed, init_params, callback, gradient_method, ansatz, custom_ansatz_circuit, clifford_fitting, clifford_fitting_num_samples, clifford_fitting_num_non_clifford_gates, enable_block_planner, planner_bond_cap, planner_trunc_tol, planner_max_layers_per_block, enable_circuit_compression, compression_block_layers, compression_optimizer_steps, compression_optimizer_lr, compression_verbose, compression_plot_loss)
#     976     qc = _instantiate_transpiled_template(gradient_param_template, param_names, params)
#     977     qc = _maybe_compress_qc(qc, None)
# --> 978     energy, expectations = _evaluate_energy_with_backend(
#     979         client,
#     980         qc,
#     981         name=f"{name}_iter{it}",
#     982         num_qubits=num_qubits,
#     983         backend=backend,
#     984         chip_name=chip_name,
#     985         shots=shots,
#     986         hamiltonian=hamiltonian,
#     987         zne=zne,
#     988         readout_mitigation=readout_mitigation,
#     989         clifford_fit_map=clifford_fit_map,
#     990         target_qubits=target_qubits_in_use,
#     991     )
#     992     grads = _parameter_shift_gradient(
#     993         client,
#     994         params,
#    (...)
#    1008         circuit_transform=_maybe_compress_qc if enable_circuit_compression else None,
#    1009     )
#    1011 grad_norm = float(np.linalg.norm(grads))
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\algorithms\vqe.py:510, in _evaluate_energy_with_backend(client, qc, name, num_qubits, backend, chip_name, shots, hamiltonian, zne, readout_mitigation, clifford_fit_map, target_qubits)
#     492 def _evaluate_energy_with_backend(
#     493     client,
#     494     qc: QuantumCircuit,
#    (...)
#     505     target_qubits: Optional[Sequence[int]] = None,
#     506 ) -> Tuple[float, Dict[str, float]]:
#     508     observables = [term[1] for term in hamiltonian]
# --> 510     result = client._run_with_backend(
#     511         qc,
#     512         name,
#     513         num_qubits,
#     514         backend=backend,
#     515         chip_name=chip_name,
#     516         shots=shots,
#     517         zne=zne,
#     518         readout_mitigation=readout_mitigation,
#     519         observables=observables,
#     520         return_probabilities=False,
#     521         print_true=False,
#     522         transpile=False,
#     523         target_qubits=target_qubits,
#     524     )
#     525     expectations_raw = _ensure_observable_map(observables, result.observable_values)
#     526     expectations = _apply_clifford_fit(expectations_raw, clifford_fit_map)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\client.py:324, in QuantumHardwareClient._run_with_backend(self, qc, name, num_qubits, backend, chip_name, shots, zne, readout_mitigation, readout_shots, observables, return_probabilities, target_qubits, merge_groups, qasm_version, print_true, transpile)
#     321 	group_counts[gi]["3"] = simulate_counts(qct_sim, shots)
#     322 else:
#     323 	# ZNE scale=3 path runs as an extra hardware task.
# --> 324 	task_id_3 = self._submit_openqasm_async(
#     325 		name=f"{name}_g{gi}_zne3",
#     326 		qasm=qct.to_openqasm2 if qasm_version == "2.0" else qct.to_openqasm3,
#     327 		shots=shots,
#     328 		chip_name=chip_name,
#     329 	)
#     330 	if print_true:
#     331 		print("[run] run circuit:", "zero-noise extrapolation")
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\client.py:134, in QuantumHardwareClient._submit_openqasm_async(self, name, qasm, shots, chip_name)
#     126 resolved_chip_name = self._resolve_chip_name(chip_name)
#     127 task = {
#     128 	"chip": resolved_chip_name,
#     129 	"name": name,
#    (...)
#     132 	"compile": False,
#     133 }
# --> 134 return self.tmgr.run(task)
#
# File D:\OneDrive\work\research\code\Quantum_control\src\quantum_hw\api\task.py:105, in Task.run(self, task, repeat)
#      96 """run a task
#      97
#      98 Args:
#    (...)
#     102     int: task id
#     103 """
#     104 # Submit a circuit to the remote hardware service.
# --> 105 time.sleep(0.2)
#     106 name = task.get('name', 'MyQuantumJob')
#     107 chip = task['chip']
#
# KeyboardInterrupt:
