# %% [markdown]
# # H2 VQE 教程（2-Qubit 压缩编码）
#
# 这个版本用于降低真实硬件线路深度：
# - 从 H2 的分子哈密顿量出发
# - 使用对称性约化后的 2-qubit 编码（SCBK）
# - 对比 `hardwareefficient` 与浅层 `custom` ansatz

# %% [markdown]
# ## 为什么可以从 4 比特继续压到 2 比特
#
# 对 H2（STO-3G）来说，原始最小模型常见是 4 个自旋轨道，对应 4 个 qubit。
# 进一步利用电子数与自旋对称性，可以做 tapering（这里用 symmetry-conserving Bravyi-Kitaev, SCBK）得到 2-qubit 有效哈密顿量。
#
# 这一步的好处：
# - 优化参数更少
# - 线路更浅
# - 对真实硬件噪声更友好
#
# 在 WSL 导出 2-qubit JSON：
# ```bash
# cd /mnt/d/OneDrive/work/research/code/Quantum_control
# ./scripts/run_wsl_export_h2_2q.sh 2.6 angstrom
# ```

# %%
from pathlib import Path
import json
import math

import numpy as np
import matplotlib.pyplot as plt

from quantum_hw import QuantumHardwareClient
from quantum_hw.algorithms import VQERunner
from quantum_hw.circuit import QuantumCircuit
import os
# Work around duplicated OpenMP runtime loading on Windows notebook kernels.
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')
R = 2.6
R_UNIT = 'angstrom'

cfg = {
    'layers': 1,
    'shots': 4096,
    'max_iters': 15,
    'learning_rate': 0.1,
    'seed': 7,
    'gradient_method': 'autograd',
    'prefer_chips': 'Simulator',
    'shift': math.pi / 2,
}

print('R =', R, R_UNIT)
print('cfg =', cfg)
# Out:
# R = 2.6 angstrom
# cfg = {'layers': 1, 'shots': 4096, 'max_iters': 15, 'learning_rate': 0.1, 'seed': 7, 'gradient_method': 'autograd', 'prefer_chips': 'Simulator', 'shift': 1.5707963267948966}

# %%
json_path = Path('../data/h2_R2.6_angstrom_sto-3g_scbk2.json')
if not json_path.exists():
    raise FileNotFoundError(
        f'Missing {json_path}. Generate it in WSL with:\n'
        'python chemistry/scripts/export_h2_terms_wsl.py --R 2.6 --unit angstrom '
        '--encoding scbk2 --output chemistry/data/h2_R2.6_angstrom_sto-3g_scbk2.json'
    )

data = json.loads(json_path.read_text(encoding='utf-8'))

h2_constant = float(data['constant'])
h2_2q_terms = [(float(c), str(obs)) for c, obs in data['terms']]
nqubits = int(data['nqubits'])
fci_energy = float(data['fci_energy'])
mapping = str(data.get('mapping', 'unknown'))

print('Loaded from:', json_path)
print('mapping:', mapping)
print('nqubits:', nqubits)
print('term_count:', len(h2_2q_terms))
print('fci_energy:', fci_energy)
print('first terms:', h2_2q_terms[:6])
# Out:
# Loaded from: ..\data\h2_R2.6_angstrom_sto-3g_scbk2.json
# mapping: symmetry_conserving_bravyi_kitaev
# nqubits: 2
# term_count: 4
# fci_energy: -0.9351960308474745
# first terms: [(0.022914730995436575, 'Z0'), (0.022914730995436616, 'Z1'), (0.2860499117473783, 'X0 X1'), (0.00027904454356436625, 'Z0 Z1')]

# %%
runner_he = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
)

res_he = runner_he.run_model(
    name='h2_2q_he',
    num_qubits=nqubits,
    model='custom',
    hamiltonian=h2_2q_terms,
    ansatz='hardwareefficient',
    prefer_chips=cfg['prefer_chips'],
)

e_he = h2_constant + res_he.best_energy
print('HE best_total =', round(e_he, 8), '| abs_err_fci =', round(abs(e_he - fci_energy), 8))
# Out:
# [vqe] prepare run: name=h2_2q_he num_qubits=2 model=custom layers=1 shots=4096 max_iters=15
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=15 layers=1 params=8 ansatz=hardwareefficient shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.178553 grad_norm=0.307417
# [vqe] iter 0 new best energy=-0.178553
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.234486 grad_norm=0.210604
# [vqe] iter 1 new best energy=-0.234486
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.267187 grad_norm=0.117976
# [vqe] iter 2 new best energy=-0.267187
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.280677 grad_norm=0.072893
# [vqe] iter 3 new best energy=-0.280677
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.282931 grad_norm=0.076084
# [vqe] iter 4 new best energy=-0.282931
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.278684 grad_norm=0.093873
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.272217 grad_norm=0.112320
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.268158 grad_norm=0.121591
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.268241 grad_norm=0.118924
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.271576 grad_norm=0.105808
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.276362 grad_norm=0.085573
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.281029 grad_norm=0.062074
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.284422 grad_norm=0.040942
# [vqe] iter 12 new best energy=-0.284422
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.286136 grad_norm=0.030013
# [vqe] iter 13 new best energy=-0.286136
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.286526 grad_norm=0.030246
# [vqe] iter 14 new best energy=-0.286526
# HE best_total = -0.93230289 | abs_err_fci = 0.00289314

# %% [markdown]
# ## 浅层 custom ansatz
# 由于目前系统的基态在|00>和|11>的子空间，所以这里构造一个非常浅的 2-qubit 模板：
# - 一次纠缠门
# - 一个可调相位
# - 一次纠缠门
#
# 相比 4-qubit UCC 模板，深度和门数都显著下降。

# %%
def build_h2_2q_shallow_ansatz() -> QuantumCircuit:
    qc = QuantumCircuit(2)
    qc.x(0)

    # basis rotation
    qc.s(1)
    qc.ryy("theta", 0, 1)
    qc.s(1)

    return qc

custom_qc = build_h2_2q_shallow_ansatz()
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 12
runner_custom = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    shift=cfg['shift'],
)

res_custom = runner_custom.run_model(
    name='h2_2q_custom',
    num_qubits=nqubits,
    model='custom',
    hamiltonian=h2_2q_terms,
    ansatz='custom',
    custom_ansatz_circuit=custom_qc,
    prefer_chips=cfg['prefer_chips'],
    init_params=[0.01],
)

e_custom = h2_constant + res_custom.best_energy
print('CUSTOM best_total =', round(e_custom, 8), '| abs_err_fci =', round(abs(e_custom - fci_energy), 8))
# Out:
# [vqe] prepare run: name=h2_2q_custom num_qubits=2 model=custom layers=1 shots=4096 max_iters=15
# [vqe] candidate chips: ['Simulator']
# [vqe] running on chip: Simulator
# [vqe] start optimization: iters=15 layers=1 params=1 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=autograd
# [vqe] iter 0 start
# [vqe] iter 0 energy=0.002581 grad_norm=0.286036
# [vqe] iter 0 new best energy=0.002581
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.025989 grad_norm=0.284892
# [vqe] iter 1 new best energy=-0.025989
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.054300 grad_norm=0.280903
# [vqe] iter 2 new best energy=-0.054300
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.082058 grad_norm=0.274111
# [vqe] iter 3 new best energy=-0.082058
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.108971 grad_norm=0.264595
# [vqe] iter 4 new best energy=-0.108971
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.134749 grad_norm=0.252473
# [vqe] iter 5 new best energy=-0.134749
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.159111 grad_norm=0.237901
# [vqe] iter 6 new best energy=-0.159111
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.181794 grad_norm=0.221081
# [vqe] iter 7 new best energy=-0.181794
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.202557 grad_norm=0.202258
# [vqe] iter 8 new best energy=-0.202557
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.221192 grad_norm=0.181720
# [vqe] iter 9 new best energy=-0.221192
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.237532 grad_norm=0.159798
# [vqe] iter 10 new best energy=-0.237532
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.251463 grad_norm=0.136863
# [vqe] iter 11 new best energy=-0.251463
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.262928 grad_norm=0.113313
# [vqe] iter 12 new best energy=-0.262928
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.271943 grad_norm=0.089573
# [vqe] iter 13 new best energy=-0.271943
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.278593 grad_norm=0.066074
# [vqe] iter 14 new best energy=-0.278593
# CUSTOM best_total = -0.92437028 | abs_err_fci = 0.01082575

# %%
rows = [
    ('hardwareefficient', res_he.energy_history, e_he),
    ('custom_shallow', res_custom.energy_history, e_custom),
]

print('=== H2 2Q comparison ===')
for name, _, e in rows:
    print(name, '| best_total =', round(e, 8), '| abs_err_fci =', round(abs(e - fci_energy), 8))

plt.figure(figsize=(7, 4))
for name, hist, _ in rows:
    plt.plot(np.array(hist) + h2_constant, marker='o', ms=3, label=name)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI energy')
plt.xlabel('Iteration')
plt.ylabel('Total energy')
plt.title(f'H2 VQE (2Q, R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === H2 2Q comparison ===
# hardwareefficient | best_total = -0.93230289 | abs_err_fci = 0.00289314
# custom_shallow | best_total = -0.92437028 | abs_err_fci = 0.01082575

# %% [markdown]
# ## 在真实硬件上运行线路
# 同时开启zne、rem和cf三种error mitigation

# %%
cfg['prefer_chips'] = 'Dongling'
cfg['zne'] = True
cfg['readout_mitigation'] = True
cfg['clifford_fitting'] = True
cfg['clifford_fitting_num_samples'] = 8
cfg['gradient_method'] = 'parameter-shift'
cfg['max_iters'] = 15
cfg['learning_rate'] = 0.1
runner_cmp = VQERunner(
    client=QuantumHardwareClient(),
    layers=cfg['layers'],
    shots=cfg['shots'],
    max_iters=cfg['max_iters'],
    learning_rate=cfg['learning_rate'],
    gradient_method=cfg['gradient_method'],
    seed=cfg['seed'],
    zne=cfg['zne'],
    readout_mitigation=cfg['readout_mitigation'],
    shift=cfg['shift'],
    clifford_fitting=cfg['clifford_fitting'],
    clifford_fitting_num_samples=cfg['clifford_fitting_num_samples']
)
    
kwargs = {
    'name': f'h2_2q_custom',
    'num_qubits': nqubits,
    'model': 'custom',
    'hamiltonian': h2_2q_terms,
    'ansatz': 'custom',
    'custom_ansatz_circuit': custom_qc,
    'prefer_chips': cfg['prefer_chips'],
    'init_params': [0.01],
}

res = runner_cmp.run_model(**kwargs)
e_total = h2_constant + res.best_energy
abs_error_fci = abs(e_total - fci_energy)

print('=== 2-Qubit H2 VQE Result ===')
print('Estimated total energy:  ', round(e_total, 8))
print('FCI reference energy:    ', round(fci_energy, 8))
print('Absolute error vs FCI:   ', round(abs_error_fci, 8))

import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 4))
plt.plot(np.array(res.energy_history) + h2_constant, marker='o', ms=3)
plt.axhline(fci_energy, color='red', linestyle='--', label='FCI Energy')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (non-constant part)')
plt.title(f'H2 VQE Convergence (R={R} {R_UNIT})')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [vqe] prepare run: name=h2_2q_custom num_qubits=2 model=custom layers=1 shots=4096 max_iters=15
# Dongling configuration loading done!
# The last calibration time was 2026-03-17 19:34:16
# [vqe] candidate chips: ['Dongling']
# Dongling configuration loading done!
# The last calibration time was 2026-03-17 19:34:16
# [vqe] running on chip: Dongling
# [vqe] clifford fitting prepared: terms=4 samples=8 non_clifford_gates=3
# [vqe] start optimization: iters=15 layers=1 params=1 ansatz=custom shots=4096 shift=1.5707963267948966 gradient=parameter-shift
# [vqe] iter 0 start
# [vqe] iter 0 energy=-0.181881 grad_norm=0.189988
# [vqe] iter 0 new best energy=-0.181881
# [vqe] iter 1 start
# [vqe] iter 1 energy=-0.216742 grad_norm=0.173579
# [vqe] iter 1 new best energy=-0.216742
# [vqe] iter 2 start
# [vqe] iter 2 energy=-0.224235 grad_norm=0.140783
# [vqe] iter 2 new best energy=-0.224235
# [vqe] iter 3 start
# [vqe] iter 3 energy=-0.261982 grad_norm=0.139135
# [vqe] iter 3 new best energy=-0.261982
# [vqe] iter 4 start
# [vqe] iter 4 energy=-0.253373 grad_norm=0.111632
# [vqe] iter 5 start
# [vqe] iter 5 energy=-0.259165 grad_norm=0.080605
# [vqe] iter 6 start
# [vqe] iter 6 energy=-0.264141 grad_norm=0.058498
# [vqe] iter 6 new best energy=-0.264141
# [vqe] iter 7 start
# [vqe] iter 7 energy=-0.271933 grad_norm=0.038165
# [vqe] iter 7 new best energy=-0.271933
# [vqe] iter 8 start
# [vqe] iter 8 energy=-0.286336 grad_norm=0.019249
# [vqe] iter 8 new best energy=-0.286336
# [vqe] iter 9 start
# [vqe] iter 9 energy=-0.271639 grad_norm=0.014907
# [vqe] iter 10 start
# [vqe] iter 10 energy=-0.277980 grad_norm=0.028884
# [vqe] iter 11 start
# [vqe] iter 11 energy=-0.287460 grad_norm=0.044962
# [vqe] iter 11 new best energy=-0.287460
# [vqe] iter 12 start
# [vqe] iter 12 energy=-0.275235 grad_norm=0.044373
# [vqe] iter 13 start
# [vqe] iter 13 energy=-0.263345 grad_norm=0.056173
# [vqe] iter 14 start
# [vqe] iter 14 energy=-0.264312 grad_norm=0.070257
# === 2-Qubit H2 VQE Result ===
# Estimated total energy:   -0.93323716
# FCI reference energy:     -0.93519603
# Absolute error vs FCI:    0.00195887
